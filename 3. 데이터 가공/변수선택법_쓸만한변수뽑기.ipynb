# %%
import pandas as pd
import sys
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm
from sklearn import linear_model
reg = linear_model.LinearRegression()

import warnings
warnings.filterwarnings("ignore")

# %%
#불러오기
merge = pd.read_csv('C:/Users/twentystones/Desktop/빅콘/02_평가데이터_update(210806)/merge2.csv', encoding='cp949', index_col=0)
merge = merge.drop(merge.index[[0,1,2,3]])
merge

#스케일링
min_max_scaler = MinMaxScaler()
fitted = min_max_scaler.fit(merge)
print(fitted.data_max_)
merge_scale = min_max_scaler.transform(merge)
merge_scale = pd.DataFrame(merge_scale, columns=merge.columns, index=merge.index)

#결측치는 스케일링했으니 중간값으로
merge_scale = merge_scale.fillna(0.5)

merge_scale
# Out:
# [1.13990000e+05 1.03571000e+05 1.17835000e+05 ... 4.09810384e+09
#  4.34464795e+09 3.71456376e+09]
#       em_cnt18_01  em_cnt18_02  em_cnt18_03  em_cnt18_04  em_cnt18_05  \
# 건입동      0.153336     0.161185     0.156232     0.155084     0.153612
# 구좌읍      0.500000     0.500000     0.500000     0.500000     0.500000
# 남원읍      0.074971     0.074429     0.076312     0.075451     0.074637
# 노형동      1.000000     1.000000     1.000000     1.000000     1.000000
# 대륜동      0.182127     0.178346     0.174841     0.174562     0.162232
# 대정읍      0.080420     0.083609     0.085012     0.086817     0.087563
# 대천동      0.169848     0.161497     0.160038     0.152333     0.150305
# 도두동      0.037481     0.038881     0.038392     0.037023     0.036414
# 동홍동      0.397128     0.412099     0.388245     0.359241     0.344871
# 봉개동      0.023050     0.024956     0.022989     0.023244     0.024510
# 삼도1동     0.242020     0.255084     0.244733     0.243783     0.242291
# 삼도2동     0.137275     0.143041     0.137075     0.134746     0.137168
# 삼양동      0.368691     0.385633     0.372645     0.365653     0.363171
# 서홍동      0.128363     0.137038     0.129206     0.123033     0.120085
# 성산읍      0.011950     0.013379     0.013603     0.012216     0.012848
# 송산동      0.043691     0.052455     0.059640     0.060692     0.056017
# 아라동      0.445364     0.456456     0.470026     0.484860     0.478825
# 안덕면      0.013793     0.014003     0.013226     0.013119     0.013285
# 알수없음     0.000000     0.000000     0.000000     0.000000     0.000000
# 애월읍      0.022988     0.021750     0.022457     0.021067     0.019494
# 연동       0.768814     0.777550     0.766796     0.774212     0.764644
# 영천동      0.042097     0.045264     0.047769     0.042194     0.034729
# 예래동      0.016335     0.017365     0.017203     0.017848     0.016335
# 오라동      0.184722     0.190137     0.185444     0.184037     0.187140
# 외도동      0.349690     0.354274     0.351765     0.348639     0.350472
# 용담1동     0.121772     0.127791     0.127526     0.125636     0.122456
# 용담2동     0.245467     0.258368     0.248350     0.246837     0.246183
# 이도1동     0.148844     0.154715     0.153832     0.150702     0.144875
# 이도2동     0.873143     0.893121     0.875611     0.879995     0.873846
# 이호동      0.051230     0.053956     0.051712     0.052493     0.053037
# 일도1동     0.041689     0.043042     0.044580     0.042662     0.040072
# 일도2동     0.590248     0.621559     0.609921     0.608847     0.598223
# 정방동      0.049476     0.049288     0.058020     0.047547     0.042077
# 조천읍      0.500000     0.500000     0.500000     0.500000     0.500000
# 중문동      0.147799     0.144795     0.143581     0.140845     0.140398
# 도두동         0.039890        0.041228        0.037409        0.037102
# 동홍동         0.274407        0.269870        0.259872        0.250851
# 봉개동         0.048293        0.056354        0.061312        0.058704
# 삼도1동        0.233362        0.237334        0.227432        0.233634
# 삼도2동        0.119719        0.116484        0.111270        0.115163
# 삼양동         0.370322        0.394775        0.375947        0.356251
# 서홍동         0.133654        0.124789        0.131319        0.121505
# 성산읍         0.113306        0.129036        0.113150        0.109271
# 송산동         0.041437        0.045733        0.040064        0.034570
# 아라동         0.566985        0.595301        0.584874        0.577184
# 안덕면         0.105172        0.117452        0.133755        0.118684
# 알수없음        0.000000        0.000000        0.000000        0.000000
# 애월읍         0.426673        0.444244        0.446959        0.443103
# 연동          0.835818        0.860295        0.828807        0.825735
# 영천동         0.051119        0.050155        0.050134        0.042073
# 예래동         0.036735        0.040283        0.039159        0.035763
# 오라동         0.279252        0.283958        0.277435        0.260817
# 외도동         0.375160        0.358791        0.369596        0.338538
# 용담1동        0.101251        0.106981        0.106461        0.102270
# 용담2동        0.213488        0.226808        0.235591        0.210296
# 이도1동        0.142798        0.143506        0.147317        0.130925
# 이도2동        0.913020        0.900061        0.892164        0.865334
# 이호동         0.058367        0.064942        0.058702        0.059075
# 일도1동        0.039832        0.044433        0.042377        0.037338
# 일도2동        0.515504        0.541435        0.501540        0.492245
# 정방동         0.013028        0.015346        0.017282        0.014734
# 조천읍         0.261960        0.271057        0.294204        0.267102
# 중문동         0.127477        0.127590        0.126107        0.119561
# 중앙동         0.031377        0.031649        0.031864        0.028064
# 천지동         0.041023        0.035536        0.032151        0.028787
# 표선면         0.089597        0.087078        0.092422        0.091560
# 한경면         0.056524        0.061694        0.063734        0.059120
# 한림읍         0.213335        0.221926        0.209790        0.230274
# 화북동         0.375368        0.372109        0.376010        0.361237
# 효돈동         0.047990        0.049068        0.049805        0.036722
#
#       use_amt한식21_06
# 건입동         0.141816
# 구좌읍         0.129150
# 남원읍         0.137086
# 노형동         1.000000
# 대륜동         0.187133
# 대정읍         0.271240
# 대천동         0.161760
# 도두동         0.035497
# 동홍동         0.276253
# 봉개동         0.061154
# 삼도1동        0.238797
# 삼도2동        0.116860
# 삼양동         0.366319
# 서홍동         0.119811
# 성산읍         0.118266
# 송산동         0.046484
# 아라동         0.616449
# 안덕면         0.127563
# 알수없음        0.000000
# 애월읍         0.455000
# 연동          0.826505
# 영천동         0.050522
# 예래동         0.035719
# 오라동         0.248576
# 외도동         0.366943
# 용담1동        0.104315
# 용담2동        0.210758
# 이도1동        0.139334
# 이도2동        0.856899
# 이호동         0.061774
# 일도1동        0.048232
# 일도2동        0.485838
# 정방동         0.017716
# 조천읍         0.269505
# 중문동         0.136082
# 중앙동         0.034826
# 천지동         0.032454
# 표선면         0.092194
# 한경면         0.064463
# 한림읍         0.235857
# 화북동         0.374859
# 효돈동         0.046521
#
# [42 rows x 1428 columns]

# %% [markdown]
# # 전체선택법 함수로 만들기

# %%
#전진선택법 함수
def forward_select(drop_col, data):
    variables = data.drop(drop_col, axis=1).columns.tolist() ## 설명 변수 리스트

    y = data[drop_col] ## 반응 변수
    global selected_variables
    selected_variables = [] ## 선택된 변수들
    sl_enter = 0.05

    sv_per_step = [] ## 각 스텝별로 선택된 변수들
    adjusted_r_squared = [] ## 각 스텝별 수정된 결정계수
    steps = [] ## 스텝
    step = 0
    while len(variables) > 0:
        remainder = list(set(variables) - set(selected_variables))
        pval = pd.Series(index=remainder) ## 변수의 p-value
        ## 기존에 포함된 변수와 새로운 변수 하나씩 돌아가면서 
        ## 선형 모형을 적합한다.
        for col in remainder: 
            X = data[selected_variables+[col]]
            X = sm.add_constant(X)
            model = sm.OLS(y,X).fit()
            pval[col] = model.pvalues[col]

        min_pval = pval.min()
        if min_pval < sl_enter: ## 최소 p-value 값이 기준 값보다 작으면 포함
            selected_variables.append(pval.idxmin())

            step += 1
            steps.append(step)
            adj_r_squared = sm.OLS(y,sm.add_constant(data[selected_variables])).fit().rsquared_adj
            adjusted_r_squared.append(adj_r_squared)
            sv_per_step.append(selected_variables.copy())
        else:
            break
            
    fig = plt.figure(figsize=(10,10))
    fig.set_facecolor('white')

    font_size = 15
    plt.xticks(steps,[f'step {s}\n'+'\n'.join(sv_per_step[i]) for i,s in enumerate(steps)], fontsize=3)
    plt.plot(steps,adjusted_r_squared, marker='o')

    plt.ylabel('Adjusted R Squared',fontsize=font_size)
    plt.grid(True)
    plt.show()

    return selected_variables


#후진소거법 함수
def backward_select(drop_col, data):
    variables = data.drop(drop_col, axis=1).columns.tolist() ## 설명 변수 리스트

    y = data[drop_col] ## 반응 변수
    global selected_variables
    selected_variables = variables ## 초기에는 모든 변수가 선택된 상태
    sl_remove = 0.05

    sv_per_step = [] ## 각 스텝별로 선택된 변수들
    adjusted_r_squared = [] ## 각 스텝별 수정된 결정계수
    steps = [] ## 스텝
    step = 0
    while len(selected_variables) > 0:
        X = sm.add_constant(data[selected_variables])
        p_vals = sm.OLS(y,X).fit().pvalues[1:] ## 절편항의 p-value는 뺀다
        max_pval = p_vals.max() ## 최대 p-value
        if max_pval >= sl_remove: ## 최대 p-value값이 기준값보다 크거나 같으면 제외
            remove_variable = p_vals.idxmax()
            selected_variables.remove(remove_variable)

            step += 1
            steps.append(step)
            adj_r_squared = sm.OLS(y,sm.add_constant(data[selected_variables])).fit().rsquared_adj
            adjusted_r_squared.append(adj_r_squared)
            sv_per_step.append(selected_variables.copy())
        else:
            break

    fig = plt.figure(figsize=(10,10))
    fig.set_facecolor('white')

    font_size = 15
    plt.xticks(steps,[f'step {s}\n'+'\n'.join(sv_per_step[i]) for i,s in enumerate(steps)], fontsize=3)
    plt.plot(steps,adjusted_r_squared, marker='o')

    plt.ylabel('Adjusted R Squared',fontsize=font_size)
    plt.grid(True)
    plt.show()

    return selected_variables



#단계별선택법 함수
def stepwise_select(drop_col, data):
    
    variables = data.drop(drop_col, axis=1).columns.tolist() ## 설명 변수 리스트

    y = data[drop_col] ## 반응 변수
    global selected_variables
    selected_variables = [] ## 선택된 변수들
    sl_enter = 0.05
    sl_remove = 0.05

    sv_per_step = [] ## 각 스텝별로 선택된 변수들
    adjusted_r_squared = [] ## 각 스텝별 수정된 결정계수
    steps = [] ## 스텝
    step = 0
    while len(variables) > 0:
        remainder = list(set(variables) - set(selected_variables))
        pval = pd.Series(index=remainder) ## 변수의 p-value
        ## 기존에 포함된 변수와 새로운 변수 하나씩 돌아가면서 
        ## 선형 모형을 적합한다.
        for col in remainder: 
            X = data[selected_variables+[col]]
            X = sm.add_constant(X)
            model = sm.OLS(y,X).fit()
            pval[col] = model.pvalues[col]

        min_pval = pval.min()
        if min_pval < sl_enter: ## 최소 p-value 값이 기준 값보다 작으면 포함
            selected_variables.append(pval.idxmin())
            ## 선택된 변수들에대해서
            ## 어떤 변수를 제거할지 고른다.
            while len(selected_variables) > 0:
                selected_X = data[selected_variables]
                selected_X = sm.add_constant(selected_X)
                selected_pval = sm.OLS(y,selected_X).fit().pvalues[1:] ## 절편항의 p-value는 뺀다
                max_pval = selected_pval.max()
                if max_pval >= sl_remove: ## 최대 p-value값이 기준값보다 크거나 같으면 제외
                    remove_variable = selected_pval.idxmax()
                    selected_variables.remove(remove_variable)
                else:
                    break

            step += 1
            steps.append(step)
            adj_r_squared = sm.OLS(y,sm.add_constant(data[selected_variables])).fit().rsquared_adj
            adjusted_r_squared.append(adj_r_squared)
            sv_per_step.append(selected_variables.copy())
        else:
            break

    fig = plt.figure(figsize=(10,10))
    fig.set_facecolor('white')

    font_size = 15
    plt.xticks(steps,[f'step {s}\n'+'\n'.join(sv_per_step[i]) for i,s in enumerate(steps)], fontsize=3)
    plt.plot(steps,adjusted_r_squared, marker='o')

    plt.ylabel('Adjusted R Squared',fontsize=font_size)
    plt.grid(True)
    plt.show()
    
    

    return selected_variables

# %%
forward_select('em_g21_06', merge_scale)
# Out:
# ['em_g21_04',
#  'use_amt부페20_08',
#  'foreign_pop남성21_02',
#  'foreign_pop남성20_10',
#  'visit_pop_cnt단기해외20_04',
#  'total_pop남성21_03']

# %%
backward_select('em_g21_06', merge_scale)
# Out:
# ['em_g18_01',
#  'em_g18_02',
#  'em_g18_03',
#  'em_g18_04',
#  'em_g18_05',
#  'em_g18_06',
#  'em_g18_07',
#  'em_g18_08',
#  'em_g18_09',
#  'em_g18_10',
#  'em_g18_11',
#  'em_g18_12',
#  'em_g19_01',
#  'em_g19_02',
#  'em_g19_03',
#  'em_g19_04',
#  'em_g19_05',
#  'em_g19_06',
#  'em_g19_07',
#  'em_g19_08',
#  'em_g19_09',
#  'em_g19_10',
#  'em_g19_11',
#  'em_g19_12',
#  'em_g20_01',
#  'em_g20_02',
#  'em_g20_03',
#  'em_g20_04',
#  'em_g20_05',
#  'em_g20_06',
#  'em_g20_07',
#  'em_g20_08',
#  'em_g20_09',
#  'em_g20_10',
#  'em_g20_11',
#  'em_g20_12',
#  'em_g21_01',
#  'em_g21_02',
#  'em_g21_03',
#  'em_g21_04',
#  'em_g21_05',
#  'resd_pop_cnt내국인남성제주18_01',
#  'resd_pop_cnt내국인남성제주18_02',
#  'resd_pop_cnt내국인남성제주18_03',
#  'resd_pop_cnt내국인남성제주18_04',
#  'resd_pop_cnt내국인남성제주18_05',
#  'resd_pop_cnt내국인남성제주18_06',
#  'resd_pop_cnt내국인남성제주18_07',
#  'resd_pop_cnt내국인남성제주18_08',
#  'resd_pop_cnt내국인남성제주18_09',
#  'resd_pop_cnt내국인남성제주18_10',
#  'resd_pop_cnt내국인남성제주18_11',
#  'resd_pop_cnt내국인남성제주18_12',
#  'resd_pop_cnt내국인남성제주19_01',
#  'resd_pop_cnt내국인남성제주19_02',
#  'resd_pop_cnt내국인남성제주19_03',
#  'resd_pop_cnt내국인남성제주19_04',
#  'resd_pop_cnt내국인남성제주19_05',
#  'resd_pop_cnt내국인남성제주19_06',
#  'resd_pop_cnt내국인남성제주19_07',
#  'resd_pop_cnt내국인남성제주19_08',
#  'resd_pop_cnt내국인남성제주19_09',
#  'resd_pop_cnt내국인남성제주19_10',
#  'resd_pop_cnt내국인남성제주19_11',
#  'resd_pop_cnt내국인남성제주19_12',
#  'resd_pop_cnt내국인남성제주20_01',
#  'resd_pop_cnt내국인남성제주20_02',
#  'resd_pop_cnt내국인남성제주20_03',
#  'resd_pop_cnt내국인남성제주20_04',
#  'resd_pop_cnt내국인남성제주20_05',
#  'resd_pop_cnt내국인남성제주20_06',
#  'resd_pop_cnt내국인남성제주20_07',
#  'resd_pop_cnt내국인남성제주20_08',
#  'resd_pop_cnt내국인남성제주20_09',
#  'resd_pop_cnt내국인남성제주20_10',
#  'resd_pop_cnt내국인남성제주20_11',
#  'resd_pop_cnt내국인남성제주20_12',
#  'resd_pop_cnt내국인남성제주21_01',
#  'resd_pop_cnt내국인남성제주21_02',
#  'resd_pop_cnt내국인남성제주21_03',
#  'resd_pop_cnt내국인남성제주21_04',
#  'resd_pop_cnt내국인남성제주21_05',
#  'resd_pop_cnt내국인남성제주21_06',
#  'resd_pop_cnt내국인여성제주18_01',
#  'resd_pop_cnt내국인여성제주18_02',
#  'resd_pop_cnt내국인여성제주18_03',
#  'resd_pop_cnt내국인여성제주18_04',
#  'resd_pop_cnt내국인여성제주18_05',
#  'resd_pop_cnt내국인여성제주18_06',
#  'resd_pop_cnt내국인여성제주18_07',
#  'resd_pop_cnt내국인여성제주18_08',
#  'resd_pop_cnt내국인여성제주18_09',
#  'resd_pop_cnt내국인여성제주18_10',
#  'resd_pop_cnt내국인여성제주18_11',
#  'resd_pop_cnt내국인여성제주18_12',
#  'resd_pop_cnt내국인여성제주19_01',
#  'resd_pop_cnt내국인여성제주19_02',
#  'resd_pop_cnt내국인여성제주19_03',
#  'resd_pop_cnt내국인여성제주19_04',
#  'resd_pop_cnt내국인여성제주19_05',
#  'resd_pop_cnt내국인여성제주19_06',
#  'resd_pop_cnt내국인여성제주19_07',
#  'resd_pop_cnt내국인여성제주19_08',
#  'resd_pop_cnt내국인여성제주19_09',
#  'resd_pop_cnt내국인여성제주19_10',
#  'resd_pop_cnt내국인여성제주19_11',
#  'resd_pop_cnt내국인여성제주19_12',
#  'resd_pop_cnt내국인여성제주20_01',
#  'resd_pop_cnt내국인여성제주20_02',
#  'resd_pop_cnt내국인여성제주20_03',
#  'resd_pop_cnt내국인여성제주20_04',
#  'resd_pop_cnt내국인여성제주20_05',
#  'resd_pop_cnt내국인여성제주20_06',
#  'resd_pop_cnt내국인여성제주20_07',
#  'resd_pop_cnt내국인여성제주20_08',
#  'resd_pop_cnt내국인여성제주20_09',
#  'resd_pop_cnt내국인여성제주20_10',
#  'resd_pop_cnt내국인여성제주20_11',
#  'resd_pop_cnt내국인여성제주20_12',
#  'resd_pop_cnt내국인여성제주21_01',
#  'resd_pop_cnt내국인여성제주21_02',
#  'resd_pop_cnt내국인여성제주21_03',
#  'resd_pop_cnt내국인여성제주21_04',
#  'resd_pop_cnt내국인여성제주21_05',
#  'resd_pop_cnt내국인여성제주21_06',
#  'visit_pop_cnt내국인남성그외18_01',
#  'visit_pop_cnt내국인남성그외18_02',
#  'visit_pop_cnt내국인남성그외18_03',
#  'visit_pop_cnt내국인남성그외18_04',
#  'visit_pop_cnt내국인남성그외18_05',
#  'visit_pop_cnt내국인남성그외18_06',
#  'visit_pop_cnt내국인남성그외18_07',
#  'visit_pop_cnt내국인남성그외18_08',
#  'visit_pop_cnt내국인남성그외18_09',
#  'visit_pop_cnt내국인남성그외18_10',
#  'visit_pop_cnt내국인남성그외18_11',
#  'visit_pop_cnt내국인남성그외18_12',
#  'visit_pop_cnt내국인남성그외19_01',
#  'visit_pop_cnt내국인남성그외19_02',
#  'visit_pop_cnt내국인남성그외19_03',
#  'visit_pop_cnt내국인남성그외19_04',
#  'visit_pop_cnt내국인남성그외19_05',
#  'visit_pop_cnt내국인남성그외19_06',
#  'visit_pop_cnt내국인남성그외19_07',
#  'visit_pop_cnt내국인남성그외19_08',
#  'visit_pop_cnt내국인남성그외19_09',
#  'visit_pop_cnt내국인남성그외19_10',
#  'visit_pop_cnt내국인남성그외19_11',
#  'visit_pop_cnt내국인남성그외19_12',
#  'visit_pop_cnt내국인남성그외20_01',
#  'visit_pop_cnt내국인남성그외20_02',
#  'visit_pop_cnt내국인남성그외20_03',
#  'visit_pop_cnt내국인남성그외20_04',
#  'visit_pop_cnt내국인남성그외20_05',
#  'visit_pop_cnt내국인남성그외20_06',
#  'visit_pop_cnt내국인남성그외20_07',
#  'visit_pop_cnt내국인남성그외20_08',
#  'visit_pop_cnt내국인남성그외20_09',
#  'visit_pop_cnt내국인남성그외20_10',
#  'visit_pop_cnt내국인남성그외20_11',
#  'visit_pop_cnt내국인남성그외20_12',
#  'visit_pop_cnt내국인남성그외21_01',
#  'visit_pop_cnt내국인남성그외21_02',
#  'visit_pop_cnt내국인남성그외21_03',
#  'visit_pop_cnt내국인남성그외21_04',
#  'visit_pop_cnt내국인남성그외21_05',
#  'visit_pop_cnt내국인남성그외21_06',
#  'visit_pop_cnt내국인남성제주18_01',
#  'visit_pop_cnt내국인남성제주18_02',
#  'visit_pop_cnt내국인남성제주18_03',
#  'visit_pop_cnt내국인남성제주18_04',
#  'visit_pop_cnt내국인남성제주18_05',
#  'visit_pop_cnt내국인남성제주18_06',
#  'visit_pop_cnt내국인남성제주18_07',
#  'visit_pop_cnt내국인남성제주18_08',
#  'visit_pop_cnt내국인남성제주18_09',
#  'visit_pop_cnt내국인남성제주18_10',
#  'visit_pop_cnt내국인남성제주18_11',
#  'visit_pop_cnt내국인남성제주18_12',
#  'visit_pop_cnt내국인남성제주19_01',
#  'visit_pop_cnt내국인남성제주19_02',
#  'visit_pop_cnt내국인남성제주19_03',
#  'visit_pop_cnt내국인남성제주19_04',
#  'visit_pop_cnt내국인남성제주19_05',
#  'visit_pop_cnt내국인남성제주19_06',
#  'visit_pop_cnt내국인남성제주19_07',
#  'visit_pop_cnt내국인남성제주19_08',
#  'visit_pop_cnt내국인남성제주19_09',
#  'visit_pop_cnt내국인남성제주19_10',
#  'visit_pop_cnt내국인남성제주19_11',
#  'visit_pop_cnt내국인남성제주19_12',
#  'visit_pop_cnt내국인남성제주20_01',
#  'visit_pop_cnt내국인남성제주20_02',
#  'visit_pop_cnt내국인남성제주20_03',
#  'visit_pop_cnt내국인남성제주20_04',
#  'visit_pop_cnt내국인남성제주20_05',
#  'visit_pop_cnt내국인남성제주20_06',
#  'visit_pop_cnt내국인남성제주20_07',
#  'visit_pop_cnt내국인남성제주20_08',
#  'visit_pop_cnt내국인남성제주20_09',
#  'visit_pop_cnt내국인남성제주20_10',
#  'visit_pop_cnt내국인남성제주20_11',
#  'visit_pop_cnt내국인남성제주20_12',
#  'visit_pop_cnt내국인남성제주21_01',
#  'visit_pop_cnt내국인남성제주21_02',
#  'visit_pop_cnt내국인남성제주21_03',
#  'visit_pop_cnt내국인남성제주21_04',
#  'visit_pop_cnt내국인남성제주21_05',
#  'visit_pop_cnt내국인남성제주21_06',
#  'visit_pop_cnt내국인여성그외18_01',
#  'visit_pop_cnt내국인여성그외18_02',
#  'visit_pop_cnt내국인여성그외18_03',
#  'visit_pop_cnt내국인여성그외18_04',
#  'visit_pop_cnt내국인여성그외18_05',
#  'visit_pop_cnt내국인여성그외18_06',
#  'visit_pop_cnt내국인여성그외18_07',
#  'visit_pop_cnt내국인여성그외18_08',
#  'visit_pop_cnt내국인여성그외18_09',
#  'visit_pop_cnt내국인여성그외18_10',
#  'visit_pop_cnt내국인여성그외18_11',
#  'visit_pop_cnt내국인여성그외18_12',
#  'visit_pop_cnt내국인여성그외19_01',
#  'visit_pop_cnt내국인여성그외19_02',
#  'visit_pop_cnt내국인여성그외19_03',
#  'visit_pop_cnt내국인여성그외19_04',
#  'visit_pop_cnt내국인여성그외19_05',
#  'visit_pop_cnt내국인여성그외19_06',
#  'visit_pop_cnt내국인여성그외19_07',
#  'visit_pop_cnt내국인여성그외19_08',
#  'visit_pop_cnt내국인여성그외19_09',
#  'visit_pop_cnt내국인여성그외19_10',
#  'visit_pop_cnt내국인여성그외19_11',
#  'visit_pop_cnt내국인여성그외19_12',
#  'visit_pop_cnt내국인여성그외20_01',
#  'visit_pop_cnt내국인여성그외20_02',
#  'visit_pop_cnt내국인여성그외20_03',
#  'visit_pop_cnt내국인여성그외20_04',
#  'visit_pop_cnt내국인여성그외20_05',
#  'visit_pop_cnt내국인여성그외20_06',
#  'visit_pop_cnt내국인여성그외20_07',
#  'visit_pop_cnt내국인여성그외20_08',
#  'visit_pop_cnt내국인여성그외20_09',
#  'visit_pop_cnt내국인여성그외20_10',
#  'visit_pop_cnt내국인여성그외20_11',
#  'visit_pop_cnt내국인여성그외20_12',
#  'visit_pop_cnt내국인여성그외21_01',
#  'visit_pop_cnt내국인여성그외21_02',
#  'visit_pop_cnt내국인여성그외21_03',
#  'visit_pop_cnt내국인여성그외21_04',
#  'visit_pop_cnt내국인여성그외21_05',
#  'visit_pop_cnt내국인여성그외21_06',
#  'visit_pop_cnt내국인여성제주18_01',
#  'visit_pop_cnt내국인여성제주18_02',
#  'visit_pop_cnt내국인여성제주18_03',
#  'visit_pop_cnt내국인여성제주18_04',
#  'visit_pop_cnt내국인여성제주18_05',
#  'visit_pop_cnt내국인여성제주18_06',
#  'visit_pop_cnt내국인여성제주18_07',
#  'visit_pop_cnt내국인여성제주18_08',
#  'visit_pop_cnt내국인여성제주18_09',
#  'visit_pop_cnt내국인여성제주18_10',
#  'visit_pop_cnt내국인여성제주18_11',
#  'visit_pop_cnt내국인여성제주18_12',
#  'visit_pop_cnt내국인여성제주19_01',
#  'visit_pop_cnt내국인여성제주19_02',
#  'visit_pop_cnt내국인여성제주19_03',
#  'visit_pop_cnt내국인여성제주19_04',
#  'visit_pop_cnt내국인여성제주19_05',
#  'visit_pop_cnt내국인여성제주19_06',
#  'visit_pop_cnt내국인여성제주19_07',
#  'visit_pop_cnt내국인여성제주19_08',
#  'visit_pop_cnt내국인여성제주19_09',
#  'visit_pop_cnt내국인여성제주19_10',
#  'visit_pop_cnt내국인여성제주19_11',
#  'visit_pop_cnt내국인여성제주19_12',
#  'visit_pop_cnt내국인여성제주20_01',
#  'visit_pop_cnt내국인여성제주20_02',
#  'visit_pop_cnt내국인여성제주20_03',
#  'visit_pop_cnt내국인여성제주20_04',
#  'visit_pop_cnt내국인여성제주20_05',
#  'visit_pop_cnt내국인여성제주20_06',
#  'visit_pop_cnt내국인여성제주20_07',
#  'visit_pop_cnt내국인여성제주20_08',
#  'visit_pop_cnt내국인여성제주20_09',
#  'visit_pop_cnt내국인여성제주20_10',
#  'visit_pop_cnt내국인여성제주20_11',
#  'visit_pop_cnt내국인여성제주20_12',
#  'visit_pop_cnt내국인여성제주21_01',
#  'visit_pop_cnt내국인여성제주21_02',
#  'visit_pop_cnt내국인여성제주21_03',
#  'visit_pop_cnt내국인여성제주21_04',
#  'visit_pop_cnt내국인여성제주21_05',
#  'visit_pop_cnt내국인여성제주21_06',
#  'work_pop_cnt내국인남성그외18_01',
#  'work_pop_cnt내국인남성그외18_02',
#  'work_pop_cnt내국인남성그외18_03',
#  'work_pop_cnt내국인남성그외18_04',
#  'work_pop_cnt내국인남성그외18_05',
#  'work_pop_cnt내국인남성그외18_06',
#  'work_pop_cnt내국인남성그외18_07',
#  'work_pop_cnt내국인남성그외18_08',
#  'work_pop_cnt내국인남성그외18_09',
#  'work_pop_cnt내국인남성그외18_10',
#  'work_pop_cnt내국인남성그외18_11',
#  'work_pop_cnt내국인남성그외18_12',
#  'work_pop_cnt내국인남성그외19_01',
#  'work_pop_cnt내국인남성그외19_02',
#  'work_pop_cnt내국인남성그외19_03',
#  'work_pop_cnt내국인남성그외19_04',
#  'work_pop_cnt내국인남성그외19_05',
#  'work_pop_cnt내국인남성그외19_06',
#  'work_pop_cnt내국인남성그외19_07',
#  'work_pop_cnt내국인남성그외19_08',
#  'work_pop_cnt내국인남성그외19_09',
#  'work_pop_cnt내국인남성그외19_10',
#  'work_pop_cnt내국인남성그외19_11',
#  'work_pop_cnt내국인남성그외19_12',
#  'work_pop_cnt내국인남성그외20_01',
#  'work_pop_cnt내국인남성그외20_02',
#  'work_pop_cnt내국인남성그외20_03',
#  'work_pop_cnt내국인남성그외20_04',
#  'work_pop_cnt내국인남성그외20_05',
#  'work_pop_cnt내국인남성그외20_06',
#  'work_pop_cnt내국인남성그외20_07',
#  'work_pop_cnt내국인남성그외20_08',
#  'work_pop_cnt내국인남성그외20_09',
#  'work_pop_cnt내국인남성그외20_10',
#  'work_pop_cnt내국인남성그외20_11',
#  'work_pop_cnt내국인남성그외20_12',
#  'work_pop_cnt내국인남성그외21_01',
#  'work_pop_cnt내국인남성그외21_02',
#  'work_pop_cnt내국인남성그외21_03',
#  'work_pop_cnt내국인남성그외21_04',
#  'work_pop_cnt내국인남성그외21_05',
#  'work_pop_cnt내국인남성그외21_06',
#  'work_pop_cnt내국인남성제주18_01',
#  'work_pop_cnt내국인남성제주18_02',
#  'work_pop_cnt내국인남성제주18_03',
#  'work_pop_cnt내국인남성제주18_04',
#  'work_pop_cnt내국인남성제주18_05',
#  'work_pop_cnt내국인남성제주18_06',
#  'work_pop_cnt내국인남성제주18_07',
#  'work_pop_cnt내국인남성제주18_08',
#  'work_pop_cnt내국인남성제주18_09',
#  'work_pop_cnt내국인남성제주18_10',
#  'work_pop_cnt내국인남성제주18_11',
#  'work_pop_cnt내국인남성제주18_12',
#  'work_pop_cnt내국인남성제주19_01',
#  'work_pop_cnt내국인남성제주19_02',
#  'work_pop_cnt내국인남성제주19_03',
#  'work_pop_cnt내국인남성제주19_04',
#  'work_pop_cnt내국인남성제주19_05',
#  'work_pop_cnt내국인남성제주19_06',
#  'work_pop_cnt내국인남성제주19_07',
#  'work_pop_cnt내국인남성제주19_08',
#  'work_pop_cnt내국인남성제주19_09',
#  'work_pop_cnt내국인남성제주19_10',
#  'work_pop_cnt내국인남성제주19_11',
#  'work_pop_cnt내국인남성제주19_12',
#  'work_pop_cnt내국인남성제주20_01',
#  'work_pop_cnt내국인남성제주20_02',
#  'work_pop_cnt내국인남성제주20_03',
#  'work_pop_cnt내국인남성제주20_04',
#  'work_pop_cnt내국인남성제주20_05',
#  'work_pop_cnt내국인남성제주20_06',
#  'work_pop_cnt내국인남성제주20_07',
#  'work_pop_cnt내국인남성제주20_08',
#  'work_pop_cnt내국인남성제주20_09',
#  'work_pop_cnt내국인남성제주20_10',
#  'work_pop_cnt내국인남성제주20_11',
#  'work_pop_cnt내국인남성제주20_12',
#  'work_pop_cnt내국인남성제주21_01',
#  'work_pop_cnt내국인남성제주21_02',
#  'work_pop_cnt내국인남성제주21_03',
#  'work_pop_cnt내국인남성제주21_04',
#  'work_pop_cnt내국인남성제주21_05',
#  'work_pop_cnt내국인남성제주21_06',
#  'work_pop_cnt내국인여성그외18_01',
#  'work_pop_cnt내국인여성그외18_02',
#  'work_pop_cnt내국인여성그외18_03',
#  'work_pop_cnt내국인여성그외18_04',
#  'work_pop_cnt내국인여성그외18_05',
#  'work_pop_cnt내국인여성그외18_06',
#  'work_pop_cnt내국인여성그외18_07',
#  'work_pop_cnt내국인여성그외18_08',
#  'work_pop_cnt내국인여성그외18_09',
#  'work_pop_cnt내국인여성그외18_10',
#  'work_pop_cnt내국인여성그외18_11',
#  'work_pop_cnt내국인여성그외18_12',
#  'work_pop_cnt내국인여성그외19_01',
#  'work_pop_cnt내국인여성그외19_02',
#  'work_pop_cnt내국인여성그외19_03',
#  'work_pop_cnt내국인여성그외19_04',
#  'work_pop_cnt내국인여성그외19_05',
#  'work_pop_cnt내국인여성그외19_06',
#  'work_pop_cnt내국인여성그외19_07',
#  'work_pop_cnt내국인여성그외19_08',
#  'work_pop_cnt내국인여성그외19_09',
#  'work_pop_cnt내국인여성그외19_10',
#  'work_pop_cnt내국인여성그외19_11',
#  'work_pop_cnt내국인여성그외19_12',
#  'work_pop_cnt내국인여성그외20_01',
#  'work_pop_cnt내국인여성그외20_02',
#  'work_pop_cnt내국인여성그외20_03',
#  'work_pop_cnt내국인여성그외20_04',
#  'work_pop_cnt내국인여성그외20_05',
#  'work_pop_cnt내국인여성그외20_06',
#  'work_pop_cnt내국인여성그외20_07',
#  'work_pop_cnt내국인여성그외20_08',
#  'work_pop_cnt내국인여성그외20_09',
#  'work_pop_cnt내국인여성그외20_10',
#  'work_pop_cnt내국인여성그외20_11',
#  'work_pop_cnt내국인여성그외20_12',
#  'work_pop_cnt내국인여성그외21_01',
#  'work_pop_cnt내국인여성그외21_02',
#  'work_pop_cnt내국인여성그외21_03',
#  'work_pop_cnt내국인여성그외21_04',
#  'work_pop_cnt내국인여성그외21_05',
#  'work_pop_cnt내국인여성그외21_06',
#  'work_pop_cnt내국인여성제주18_01',
#  'work_pop_cnt내국인여성제주18_02',
#  'work_pop_cnt내국인여성제주18_03',
#  'work_pop_cnt내국인여성제주18_04',
#  'work_pop_cnt내국인여성제주18_05',
#  'work_pop_cnt내국인여성제주18_06',
#  'work_pop_cnt내국인여성제주18_07',
#  'work_pop_cnt내국인여성제주18_08',
#  'work_pop_cnt내국인여성제주18_09',
#  'work_pop_cnt내국인여성제주18_10',
#  'work_pop_cnt내국인여성제주18_11',
#  'work_pop_cnt내국인여성제주18_12',
#  'work_pop_cnt내국인여성제주19_01',
#  'work_pop_cnt내국인여성제주19_02',
#  'work_pop_cnt내국인여성제주19_03',
#  'work_pop_cnt내국인여성제주19_04',
#  'work_pop_cnt내국인여성제주19_05',
#  'work_pop_cnt내국인여성제주19_06',
#  'work_pop_cnt내국인여성제주19_07',
#  'work_pop_cnt내국인여성제주19_08',
#  'work_pop_cnt내국인여성제주19_09',
#  'work_pop_cnt내국인여성제주19_10',
#  'work_pop_cnt내국인여성제주19_11',
#  'work_pop_cnt내국인여성제주19_12',
#  'work_pop_cnt내국인여성제주20_01',
#  'work_pop_cnt내국인여성제주20_02',
#  'work_pop_cnt내국인여성제주20_03',
#  'work_pop_cnt내국인여성제주20_04',
#  'work_pop_cnt내국인여성제주20_05',
#  'work_pop_cnt내국인여성제주20_06',
#  'work_pop_cnt내국인여성제주20_07',
#  'work_pop_cnt내국인여성제주20_08',
#  'work_pop_cnt내국인여성제주20_09',
#  'work_pop_cnt내국인여성제주20_10',
#  'work_pop_cnt내국인여성제주20_11',
#  'work_pop_cnt내국인여성제주20_12',
#  'work_pop_cnt내국인여성제주21_01',
#  'work_pop_cnt내국인여성제주21_02',
#  'work_pop_cnt내국인여성제주21_03',
#  'work_pop_cnt내국인여성제주21_04',
#  'work_pop_cnt내국인여성제주21_05',
#  'work_pop_cnt내국인여성제주21_06',
#  'resd_pop_cnt장기해외제주18_01',
#  'resd_pop_cnt장기해외제주18_02',
#  'resd_pop_cnt장기해외제주18_03',
#  'resd_pop_cnt장기해외제주18_04',
#  'resd_pop_cnt장기해외제주18_05',
#  'resd_pop_cnt장기해외제주18_06',
#  'resd_pop_cnt장기해외제주18_07',
#  'resd_pop_cnt장기해외제주18_08',
#  'resd_pop_cnt장기해외제주18_09',
#  'resd_pop_cnt장기해외제주18_10',
#  'resd_pop_cnt장기해외제주18_11',
#  'resd_pop_cnt장기해외제주18_12',
#  'resd_pop_cnt장기해외제주19_01',
#  'resd_pop_cnt장기해외제주19_02',
#  'resd_pop_cnt장기해외제주19_03',
#  'resd_pop_cnt장기해외제주19_04',
#  'resd_pop_cnt장기해외제주19_05',
#  'resd_pop_cnt장기해외제주19_06',
#  'resd_pop_cnt장기해외제주19_07',
#  'resd_pop_cnt장기해외제주19_08',
#  'resd_pop_cnt장기해외제주19_09',
#  'resd_pop_cnt장기해외제주19_10',
#  'resd_pop_cnt장기해외제주19_11',
#  'resd_pop_cnt장기해외제주19_12',
#  'resd_pop_cnt장기해외제주20_01',
#  'resd_pop_cnt장기해외제주20_02',
#  'resd_pop_cnt장기해외제주20_03',
#  'resd_pop_cnt장기해외제주20_04',
#  'resd_pop_cnt장기해외제주20_05',
#  'resd_pop_cnt장기해외제주20_06',
#  'resd_pop_cnt장기해외제주20_07',
#  'resd_pop_cnt장기해외제주20_08',
#  'resd_pop_cnt장기해외제주20_09',
#  'resd_pop_cnt장기해외제주20_10',
#  'resd_pop_cnt장기해외제주20_11',
#  'resd_pop_cnt장기해외제주20_12',
#  'resd_pop_cnt장기해외제주21_01',
#  'resd_pop_cnt장기해외제주21_02',
#  'resd_pop_cnt장기해외제주21_03',
#  'resd_pop_cnt장기해외제주21_04',
#  'resd_pop_cnt장기해외제주21_05',
#  'resd_pop_cnt장기해외제주21_06',
#  'visit_pop_cnt장기해외그외18_01',
#  'visit_pop_cnt장기해외그외18_02',
#  'visit_pop_cnt장기해외그외18_03',
#  'visit_pop_cnt장기해외그외18_04',
#  'visit_pop_cnt장기해외그외18_05',
#  'visit_pop_cnt장기해외그외18_06',
#  'visit_pop_cnt장기해외그외18_07',
#  'visit_pop_cnt장기해외그외18_08',
#  'visit_pop_cnt장기해외그외18_09',
#  'visit_pop_cnt장기해외그외18_10',
#  'visit_pop_cnt장기해외그외18_11',
#  'visit_pop_cnt장기해외그외18_12',
#  'visit_pop_cnt장기해외그외19_01',
#  'visit_pop_cnt장기해외그외19_02',
#  'visit_pop_cnt장기해외그외19_03',
#  'visit_pop_cnt장기해외그외19_04',
#  'visit_pop_cnt장기해외그외19_05',
#  'visit_pop_cnt장기해외그외19_06',
#  'visit_pop_cnt장기해외그외19_07',
#  'visit_pop_cnt장기해외그외19_08',
#  'visit_pop_cnt장기해외그외19_09',
#  'visit_pop_cnt장기해외그외19_10',
#  'visit_pop_cnt장기해외그외19_11',
#  'visit_pop_cnt장기해외그외19_12',
#  'visit_pop_cnt장기해외그외20_01',
#  'visit_pop_cnt장기해외그외20_02',
#  'visit_pop_cnt장기해외그외20_03',
#  'visit_pop_cnt장기해외그외20_04',
#  'visit_pop_cnt장기해외그외20_05',
#  'visit_pop_cnt장기해외그외20_06',
#  'visit_pop_cnt장기해외그외20_07',
#  'visit_pop_cnt장기해외그외20_08',
#  'visit_pop_cnt장기해외그외20_09',
#  'visit_pop_cnt장기해외그외20_10',
#  'visit_pop_cnt장기해외그외20_11',
#  'visit_pop_cnt장기해외그외20_12',
#  'visit_pop_cnt장기해외그외21_01',
#  'visit_pop_cnt장기해외그외21_02',
#  'visit_pop_cnt장기해외그외21_03',
#  'visit_pop_cnt장기해외그외21_04',
#  'visit_pop_cnt장기해외그외21_05',
#  'visit_pop_cnt장기해외그외21_06',
#  'visit_pop_cnt장기해외제주18_01',
#  'visit_pop_cnt장기해외제주18_02',
#  'visit_pop_cnt장기해외제주18_03',
#  'visit_pop_cnt장기해외제주18_04',
#  'visit_pop_cnt장기해외제주18_05',
#  'visit_pop_cnt장기해외제주18_06',
#  'visit_pop_cnt장기해외제주18_07',
#  'visit_pop_cnt장기해외제주18_08',
#  'visit_pop_cnt장기해외제주18_09',
#  'visit_pop_cnt장기해외제주18_10',
#  'visit_pop_cnt장기해외제주18_11',
#  'visit_pop_cnt장기해외제주18_12',
#  'visit_pop_cnt장기해외제주19_01',
#  'visit_pop_cnt장기해외제주19_02',
#  'visit_pop_cnt장기해외제주19_03',
#  'visit_pop_cnt장기해외제주19_04',
#  'visit_pop_cnt장기해외제주19_05',
#  'visit_pop_cnt장기해외제주19_06',
#  'visit_pop_cnt장기해외제주19_07',
#  'visit_pop_cnt장기해외제주19_08',
#  'visit_pop_cnt장기해외제주19_09',
#  'visit_pop_cnt장기해외제주19_10',
#  'visit_pop_cnt장기해외제주19_11',
#  'visit_pop_cnt장기해외제주19_12',
#  'visit_pop_cnt장기해외제주20_01',
#  'visit_pop_cnt장기해외제주20_02',
#  'visit_pop_cnt장기해외제주20_03',
#  'visit_pop_cnt장기해외제주20_04',
#  'visit_pop_cnt장기해외제주20_05',
#  'visit_pop_cnt장기해외제주20_06',
#  'visit_pop_cnt장기해외제주20_07',
#  'visit_pop_cnt장기해외제주20_08',
#  'visit_pop_cnt장기해외제주20_09',
#  'visit_pop_cnt장기해외제주20_10',
#  'visit_pop_cnt장기해외제주20_11',
#  'visit_pop_cnt장기해외제주20_12',
#  'visit_pop_cnt장기해외제주21_01',
#  'visit_pop_cnt장기해외제주21_02',
#  'visit_pop_cnt장기해외제주21_03',
#  'visit_pop_cnt장기해외제주21_04',
#  'visit_pop_cnt장기해외제주21_05',
#  'visit_pop_cnt장기해외제주21_06',
#  'work_pop_cnt장기해외그외18_01',
#  'work_pop_cnt장기해외그외18_02',
#  'work_pop_cnt장기해외그외18_03',
#  'work_pop_cnt장기해외그외18_04',
#  'work_pop_cnt장기해외그외18_05',
#  'work_pop_cnt장기해외그외18_06',
#  'work_pop_cnt장기해외그외18_07',
#  'work_pop_cnt장기해외그외18_08',
#  'work_pop_cnt장기해외그외18_09',
#  'work_pop_cnt장기해외그외18_10',
#  'work_pop_cnt장기해외그외18_11',
#  'work_pop_cnt장기해외그외18_12',
#  'work_pop_cnt장기해외그외19_01',
#  'work_pop_cnt장기해외그외19_02',
#  'work_pop_cnt장기해외그외19_03',
#  'work_pop_cnt장기해외그외19_04',
#  'work_pop_cnt장기해외그외19_05',
#  'work_pop_cnt장기해외그외19_06',
#  'work_pop_cnt장기해외그외19_07',
#  'work_pop_cnt장기해외그외19_08',
#  'work_pop_cnt장기해외그외19_09',
#  'work_pop_cnt장기해외그외19_10',
#  'work_pop_cnt장기해외그외19_11',
#  'work_pop_cnt장기해외그외19_12',
#  'work_pop_cnt장기해외그외20_01',
#  'work_pop_cnt장기해외그외20_02',
#  'work_pop_cnt장기해외그외20_03',
#  'work_pop_cnt장기해외그외20_04',
#  'work_pop_cnt장기해외그외20_05',
#  'work_pop_cnt장기해외그외20_06',
#  'work_pop_cnt장기해외그외20_07',
#  'work_pop_cnt장기해외그외20_08',
#  'work_pop_cnt장기해외그외20_09',
#  'work_pop_cnt장기해외그외20_10',
#  'work_pop_cnt장기해외그외20_11',
#  'work_pop_cnt장기해외그외20_12',
#  'work_pop_cnt장기해외그외21_01',
#  'work_pop_cnt장기해외그외21_02',
#  'work_pop_cnt장기해외그외21_03',
#  'work_pop_cnt장기해외그외21_04',
#  'work_pop_cnt장기해외그외21_05',
#  'work_pop_cnt장기해외그외21_06',
#  'work_pop_cnt장기해외제주18_01',
#  'work_pop_cnt장기해외제주18_02',
#  'work_pop_cnt장기해외제주18_03',
#  'work_pop_cnt장기해외제주18_04',
#  'work_pop_cnt장기해외제주18_05',
#  'work_pop_cnt장기해외제주18_06',
#  'work_pop_cnt장기해외제주18_07',
#  'work_pop_cnt장기해외제주18_08',
#  'work_pop_cnt장기해외제주18_09',
#  'work_pop_cnt장기해외제주18_10',
#  'work_pop_cnt장기해외제주18_11',
#  'work_pop_cnt장기해외제주18_12',
#  'work_pop_cnt장기해외제주19_01',
#  'work_pop_cnt장기해외제주19_02',
#  'work_pop_cnt장기해외제주19_03',
#  'work_pop_cnt장기해외제주19_04',
#  'work_pop_cnt장기해외제주19_05',
#  'work_pop_cnt장기해외제주19_06',
#  'work_pop_cnt장기해외제주19_07',
#  'work_pop_cnt장기해외제주19_08',
#  'work_pop_cnt장기해외제주19_09',
#  'work_pop_cnt장기해외제주19_10',
#  'work_pop_cnt장기해외제주19_11',
#  'work_pop_cnt장기해외제주19_12',
#  'work_pop_cnt장기해외제주20_01',
#  'work_pop_cnt장기해외제주20_02',
#  'work_pop_cnt장기해외제주20_03',
#  'work_pop_cnt장기해외제주20_04',
#  'work_pop_cnt장기해외제주20_05',
#  'work_pop_cnt장기해외제주20_06',
#  'work_pop_cnt장기해외제주20_07',
#  'work_pop_cnt장기해외제주20_08',
#  'work_pop_cnt장기해외제주20_09',
#  'work_pop_cnt장기해외제주20_10',
#  'work_pop_cnt장기해외제주20_11',
#  'work_pop_cnt장기해외제주20_12',
#  'work_pop_cnt장기해외제주21_01',
#  'work_pop_cnt장기해외제주21_02',
#  'work_pop_cnt장기해외제주21_03',
#  'work_pop_cnt장기해외제주21_04',
#  'work_pop_cnt장기해외제주21_05',
#  'work_pop_cnt장기해외제주21_06',
#  'visit_pop_cnt단기해외18_01',
#  'visit_pop_cnt단기해외18_02',
#  'visit_pop_cnt단기해외18_03',
#  'visit_pop_cnt단기해외18_04',
#  'visit_pop_cnt단기해외18_05',
#  'visit_pop_cnt단기해외18_06',
#  'visit_pop_cnt단기해외18_07',
#  'visit_pop_cnt단기해외18_08',
#  'visit_pop_cnt단기해외18_09',
#  'visit_pop_cnt단기해외18_10',
#  'visit_pop_cnt단기해외18_11',
#  'visit_pop_cnt단기해외18_12',
#  'visit_pop_cnt단기해외19_01',
#  'visit_pop_cnt단기해외19_02',
#  'visit_pop_cnt단기해외19_03',
#  'visit_pop_cnt단기해외19_04',
#  'visit_pop_cnt단기해외19_05',
#  'visit_pop_cnt단기해외19_06',
#  'visit_pop_cnt단기해외19_07',
#  'visit_pop_cnt단기해외19_08',
#  'visit_pop_cnt단기해외19_09',
#  'visit_pop_cnt단기해외19_10',
#  'visit_pop_cnt단기해외19_11',
#  'visit_pop_cnt단기해외19_12',
#  'visit_pop_cnt단기해외20_01',
#  'visit_pop_cnt단기해외20_02',
#  'visit_pop_cnt단기해외20_03',
#  'visit_pop_cnt단기해외20_04',
#  'visit_pop_cnt단기해외20_05',
#  'visit_pop_cnt단기해외20_06',
#  'visit_pop_cnt단기해외20_07',
#  'visit_pop_cnt단기해외20_08',
#  'visit_pop_cnt단기해외20_09',
#  'visit_pop_cnt단기해외20_10',
#  'visit_pop_cnt단기해외20_11',
#  'visit_pop_cnt단기해외20_12',
#  'visit_pop_cnt단기해외21_01',
#  'visit_pop_cnt단기해외21_02',
#  'visit_pop_cnt단기해외21_03',
#  'visit_pop_cnt단기해외21_04',
#  'visit_pop_cnt단기해외21_05',
#  'visit_pop_cnt단기해외21_06',
#  'foreign_pop남성18_01',
#  'foreign_pop남성18_02',
#  'foreign_pop남성18_03',
#  'foreign_pop남성18_04',
#  'foreign_pop남성18_05',
#  'foreign_pop남성18_06',
#  'foreign_pop남성18_07',
#  'foreign_pop남성18_08',
#  'foreign_pop남성18_09',
#  'foreign_pop남성18_10',
#  'foreign_pop남성18_11',
#  'foreign_pop남성18_12',
#  'foreign_pop남성19_01',
#  'foreign_pop남성19_02',
#  'foreign_pop남성19_03',
#  'foreign_pop남성19_04',
#  'foreign_pop남성19_05',
#  'foreign_pop남성19_06',
#  'foreign_pop남성19_07',
#  'foreign_pop남성19_08',
#  'foreign_pop남성19_09',
#  'foreign_pop남성19_10',
#  'foreign_pop남성19_11',
#  'foreign_pop남성19_12',
#  'foreign_pop남성20_01',
#  'foreign_pop남성20_02',
#  'foreign_pop남성20_03',
#  'foreign_pop남성20_04',
#  'foreign_pop남성20_05',
#  'foreign_pop남성20_06',
#  'foreign_pop남성20_07',
#  'foreign_pop남성20_08',
#  'foreign_pop남성20_09',
#  'foreign_pop남성20_10',
#  'foreign_pop남성20_11',
#  'foreign_pop남성20_12',
#  'foreign_pop남성21_01',
#  'foreign_pop남성21_02',
#  'foreign_pop남성21_03',
#  'foreign_pop남성21_04',
#  'foreign_pop남성21_05',
#  'foreign_pop남성21_06',
#  'foreign_pop여성18_01',
#  'foreign_pop여성18_02',
#  'foreign_pop여성18_03',
#  'foreign_pop여성18_04',
#  'foreign_pop여성18_05',
#  'foreign_pop여성18_06',
#  'foreign_pop여성18_07',
#  'foreign_pop여성18_08',
#  'foreign_pop여성18_09',
#  'foreign_pop여성18_10',
#  'foreign_pop여성18_11',
#  'foreign_pop여성18_12',
#  'foreign_pop여성19_01',
#  'foreign_pop여성19_02',
#  'foreign_pop여성19_03',
#  'foreign_pop여성19_04',
#  'foreign_pop여성19_05',
#  'foreign_pop여성19_06',
#  'foreign_pop여성19_07',
#  'foreign_pop여성19_08',
#  'foreign_pop여성19_09',
#  'foreign_pop여성19_10',
#  'foreign_pop여성19_11',
#  'foreign_pop여성19_12',
#  'foreign_pop여성20_01',
#  'foreign_pop여성20_02',
#  'foreign_pop여성20_03',
#  'foreign_pop여성20_04',
#  'foreign_pop여성20_05',
#  'foreign_pop여성20_06',
#  'foreign_pop여성20_07',
#  'foreign_pop여성20_08',
#  'foreign_pop여성20_09',
#  'foreign_pop여성20_10',
#  'foreign_pop여성20_11',
#  'foreign_pop여성20_12',
#  'foreign_pop여성21_01',
#  'foreign_pop여성21_02',
#  'foreign_pop여성21_03',
#  'foreign_pop여성21_04',
#  'foreign_pop여성21_05',
#  'foreign_pop여성21_06',
#  'resid_reg_pop남성18_01',
#  'resid_reg_pop남성18_02',
#  'resid_reg_pop남성18_03',
#  'resid_reg_pop남성18_04',
#  'resid_reg_pop남성18_05',
#  'resid_reg_pop남성18_06',
#  'resid_reg_pop남성18_07',
#  'resid_reg_pop남성18_08',
#  'resid_reg_pop남성18_09',
#  'resid_reg_pop남성18_10',
#  'resid_reg_pop남성18_11',
#  'resid_reg_pop남성18_12',
#  'resid_reg_pop남성19_01',
#  'resid_reg_pop남성19_02',
#  'resid_reg_pop남성19_03',
#  'resid_reg_pop남성19_04',
#  'resid_reg_pop남성19_05',
#  'resid_reg_pop남성19_06',
#  'resid_reg_pop남성19_07',
#  'resid_reg_pop남성19_08',
#  'resid_reg_pop남성19_09',
#  'resid_reg_pop남성19_10',
#  'resid_reg_pop남성19_11',
#  'resid_reg_pop남성19_12',
#  'resid_reg_pop남성20_01',
#  'resid_reg_pop남성20_02',
#  'resid_reg_pop남성20_03',
#  'resid_reg_pop남성20_04',
#  'resid_reg_pop남성20_05',
#  'resid_reg_pop남성20_06',
#  'resid_reg_pop남성20_07',
#  'resid_reg_pop남성20_08',
#  'resid_reg_pop남성20_09',
#  'resid_reg_pop남성20_10',
#  'resid_reg_pop남성20_11',
#  'resid_reg_pop남성20_12',
#  'resid_reg_pop남성21_01',
#  'resid_reg_pop남성21_02',
#  'resid_reg_pop남성21_03',
#  'resid_reg_pop남성21_04',
#  'resid_reg_pop남성21_05',
#  'resid_reg_pop남성21_06',
#  'resid_reg_pop여성18_01',
#  'resid_reg_pop여성18_02',
#  'resid_reg_pop여성18_03',
#  'resid_reg_pop여성18_04',
#  'resid_reg_pop여성18_05',
#  'resid_reg_pop여성18_06',
#  'resid_reg_pop여성18_07',
#  'resid_reg_pop여성18_08',
#  'resid_reg_pop여성18_09',
#  'resid_reg_pop여성18_10',
#  'resid_reg_pop여성18_11',
#  'resid_reg_pop여성18_12',
#  'resid_reg_pop여성19_01',
#  'resid_reg_pop여성19_02',
#  'resid_reg_pop여성19_03',
#  'resid_reg_pop여성19_04',
#  'resid_reg_pop여성19_05',
#  'resid_reg_pop여성19_06',
#  'resid_reg_pop여성19_07',
#  'resid_reg_pop여성19_08',
#  'resid_reg_pop여성19_09',
#  'resid_reg_pop여성19_10',
#  'resid_reg_pop여성19_11',
#  'resid_reg_pop여성19_12',
#  'resid_reg_pop여성20_01',
#  'resid_reg_pop여성20_02',
#  'resid_reg_pop여성20_03',
#  'resid_reg_pop여성20_04',
#  'resid_reg_pop여성20_05',
#  'resid_reg_pop여성20_06',
#  'resid_reg_pop여성20_07',
#  'resid_reg_pop여성20_08',
#  'resid_reg_pop여성20_09',
#  'resid_reg_pop여성20_10',
#  'resid_reg_pop여성20_11',
#  'resid_reg_pop여성20_12',
#  'resid_reg_pop여성21_01',
#  'resid_reg_pop여성21_02',
#  'resid_reg_pop여성21_03',
#  'resid_reg_pop여성21_04',
#  'resid_reg_pop여성21_05',
#  'resid_reg_pop여성21_06',
#  'total_pop남성18_01',
#  'total_pop남성18_02',
#  'total_pop남성18_03',
#  'total_pop남성18_04',
#  'total_pop남성18_05',
#  'total_pop남성18_06',
#  'total_pop남성18_07',
#  'total_pop남성18_08',
#  'total_pop남성18_09',
#  'total_pop남성18_10',
#  'total_pop남성18_11',
#  'total_pop남성18_12',
#  'total_pop남성19_01',
#  'total_pop남성19_02',
#  'total_pop남성19_03',
#  'total_pop남성19_04',
#  'total_pop남성19_05',
#  'total_pop남성19_06',
#  'total_pop남성19_07',
#  'total_pop남성19_08',
#  'total_pop남성19_09',
#  'total_pop남성19_10',
#  'total_pop남성19_11',
#  'total_pop남성19_12',
#  'total_pop남성20_01',
#  'total_pop남성20_02',
#  'total_pop남성20_03',
#  'total_pop남성20_04',
#  'total_pop남성20_05',
#  'total_pop남성20_06',
#  'total_pop남성20_07',
#  'total_pop남성20_08',
#  'total_pop남성20_09',
#  'total_pop남성20_10',
#  'total_pop남성20_11',
#  'total_pop남성20_12',
#  'total_pop남성21_01',
#  'total_pop남성21_02',
#  'total_pop남성21_03',
#  'total_pop남성21_04',
#  'total_pop남성21_05',
#  'total_pop남성21_06',
#  'total_pop여성18_01',
#  'total_pop여성18_02',
#  'total_pop여성18_03',
#  'total_pop여성18_04',
#  'total_pop여성18_05',
#  'total_pop여성18_06',
#  'total_pop여성18_07',
#  'total_pop여성18_08',
#  'total_pop여성18_09',
#  'total_pop여성18_10',
#  'total_pop여성18_11',
#  'total_pop여성18_12',
#  'total_pop여성19_01',
#  'total_pop여성19_02',
#  'total_pop여성19_03',
#  'total_pop여성19_04',
#  'total_pop여성19_05',
#  'total_pop여성19_06',
#  'total_pop여성19_07',
#  'total_pop여성19_08',
#  'total_pop여성19_09',
#  'total_pop여성19_10',
#  'total_pop여성19_11',
#  'total_pop여성19_12',
#  'total_pop여성20_01',
#  'total_pop여성20_02',
#  'total_pop여성20_03',
#  'total_pop여성20_04',
#  'total_pop여성20_05',
#  'total_pop여성20_06',
#  'total_pop여성20_07',
#  'total_pop여성20_08',
#  'total_pop여성20_09',
#  'total_pop여성20_10',
#  'total_pop여성20_11',
#  'total_pop여성20_12',
#  'total_pop여성21_01',
#  'total_pop여성21_02',
#  'total_pop여성21_03',
#  'total_pop여성21_04',
#  'total_pop여성21_05',
#  'total_pop여성21_06',
#  'use_amt간식18_01',
#  'use_amt간식18_02',
#  'use_amt간식18_03',
#  'use_amt간식18_04',
#  'use_amt간식18_05',
#  'use_amt간식18_06',
#  'use_amt간식18_07',
#  'use_amt간식18_08',
#  'use_amt간식18_09',
#  'use_amt간식18_10',
#  'use_amt간식18_11',
#  'use_amt간식18_12',
#  'use_amt간식19_01',
#  'use_amt간식19_02',
#  'use_amt간식19_03',
#  'use_amt간식19_04',
#  'use_amt간식19_05',
#  'use_amt간식19_06',
#  'use_amt간식19_07',
#  'use_amt간식19_08',
#  'use_amt간식19_09',
#  'use_amt간식19_10',
#  'use_amt간식19_11',
#  'use_amt간식19_12',
#  'use_amt간식20_01',
#  'use_amt간식20_02',
#  'use_amt간식20_03',
#  'use_amt간식20_04',
#  'use_amt간식20_05',
#  'use_amt간식20_06',
#  'use_amt간식20_07',
#  'use_amt간식20_08',
#  'use_amt간식20_09',
#  'use_amt간식20_10',
#  'use_amt간식20_11',
#  ...]

# %%
stepwise_select('em_g21_06', merge_scale)
# Out:
# ['em_g21_04',
#  'use_amt부페20_08',
#  'foreign_pop남성21_02',
#  'foreign_pop남성20_10',
#  'visit_pop_cnt단기해외20_04',
#  'total_pop남성21_03']

# %% [markdown]
# # 1. 월단위

# %%
#그냥 월단위로 정렬
selected_list=[]
month=[]
for j in ['01','02','03','04','05','06','07','08','09','10','11','12']:
    for i in merge_scale.columns.tolist():
        if i[-2:] == j:
            month.append(i)
merge_scale[month]
# Out:
#       em_g18_01  em_g19_01  em_g20_01  em_g21_01  resd_pop_cnt내국인남성제주18_01  \
# 건입동    0.147323   0.162565   0.191285   0.141328                  0.123476
# 구좌읍    0.500000   0.500000   0.087337   0.094080                  0.226935
# 남원읍    0.134850   0.157479   0.291444   0.222251                  0.246782
#       use_amt한식20_12
# 건입동         0.141678
# 구좌읍         0.119660
# 남원읍         0.181273
# 노형동         1.000000
# 대륜동         0.170319
# 대정읍         0.239758
# 대천동         0.181984
# 도두동         0.047804
# 동홍동         0.296462
# 봉개동         0.051402
# 삼도1동        0.230367
# 삼도2동        0.119167
# 삼양동         0.377195
# 서홍동         0.135919
# 성산읍         0.119262
# 송산동         0.042449
# 아라동         0.597124
# 안덕면         0.131519
# 알수없음        0.000000
# 애월읍         0.445510
# 연동          0.840797
# 영천동         0.058351
# 예래동         0.037010
# 오라동         0.291622
# 외도동         0.364368
# 용담1동        0.106010
# 용담2동        0.217292
# 이도1동        0.134698
# 이도2동        0.905466
# 이호동         0.056388
# 일도1동        0.059128
# 일도2동        0.523894
# 정방동         0.009838
# 조천읍         0.281439
# 중문동         0.132511
# 중앙동         0.033508
# 천지동         0.036213
# 표선면         0.109421
# 한경면         0.053057
# 한림읍         0.218554
# 화북동         0.387039
# 효돈동         0.056455
#
# [42 rows x 1428 columns]

# %%
#A월 변수로 A월 예측 칼럼만 뽑기

dic={ }

selected_list=[]
for j in ['01','02','03','04','05','06','07','08','09','10','11','12']:
    month=[]
    
    for i in merge_scale.columns.tolist():
        if i[-2:] == j:
            month.append(i)
    merge_scale[month]

    print(j)
    if j in ['01','02','03','04','05','06']:
        print(forward_select('em_g21_'+j, merge_scale[month]))
        dic[j+'fore'] = selected_variables
                    #print(backward_select('em_g21_'+j, merge_scale[month]))
        print(stepwise_select('em_g21_'+j, merge_scale[month]))
        dic[j+'step'] = selected_variables
    elif j in ['07','08','09','10','11','12']:
        print(forward_select('em_g20_'+j, merge_scale[month]))
        dic[j+'fore'] = selected_variables
                    #print(backward_select('em_g21_'+j, merge_scale[month]))
        print(stepwise_select('em_g20_'+j, merge_scale[month]))
        dic[j+'step'] = selected_variables

#데이터프레임으로 만들고 저장
select_result = pd.DataFrame.from_dict(dic, orient='index')
select_result.to_csv('배출량과 배출비용 뺀 전진단계별 결과.csv',encoding='cp949')
select_result
# Out:
# 01
# ['em_g20_01', 'use_amt아시아음식21_01']
# ['em_g20_01', 'use_amt아시아음식21_01']
# 02
# ['use_amt마트/슈퍼마켓19_02', 'em_g20_02', 'foreign_pop여성21_02', 'use_amt식품18_02', 'use_amt패스트푸드18_02']
# ['use_amt마트/슈퍼마켓19_02', 'em_g20_02', 'use_amt식품18_02', 'use_amt패스트푸드18_02']
# 03
# ['use_amt패스트푸드19_03', 'use_amt마트/슈퍼마켓18_03', 'use_amt농축수산물19_03', 'use_amt양식20_03']
# ['use_amt마트/슈퍼마켓18_03', 'use_amt농축수산물19_03', 'use_amt양식20_03']
# 04
# ['use_amt패스트푸드19_04', 'foreign_pop남성20_04', 'work_pop_cnt내국인여성제주19_04', 'use_amt패스트푸드18_04']
# ['foreign_pop남성20_04', 'work_pop_cnt내국인여성제주19_04', 'use_amt패스트푸드18_04']
# 05
# ['use_amt패스트푸드19_05', 'foreign_pop남성20_05', 'work_pop_cnt내국인여성그외18_05', 'work_pop_cnt내국인남성그외20_05', 'use_amt부페20_05', 'visit_pop_cnt장기해외그외18_05', 'total_pop여성18_05', 'use_amt양식20_05']
# ['use_amt패스트푸드19_05', 'foreign_pop남성20_05', 'work_pop_cnt내국인여성그외18_05', 'work_pop_cnt내국인남성그외20_05', 'use_amt부페20_05', 'visit_pop_cnt장기해외그외18_05', 'total_pop여성18_05', 'use_amt양식20_05']
# 06
# ['em_g20_06', 'use_amt식품20_06', 'foreign_pop남성21_06', 'use_amt부페20_06', 'visit_pop_cnt장기해외그외20_06', 'visit_pop_cnt장기해외그외19_06', 'work_pop_cnt장기해외제주20_06']
# ['em_g20_06', 'use_amt식품20_06', 'foreign_pop남성21_06', 'use_amt부페20_06', 'visit_pop_cnt장기해외그외20_06', 'visit_pop_cnt장기해외그외19_06', 'work_pop_cnt장기해외제주20_06']
# 07
# ['use_amt한식18_07', 'use_amt농축수산물20_07', 'use_amt양식19_07']
# ['use_amt한식18_07', 'use_amt농축수산물20_07', 'use_amt양식19_07']
# 08
# ['use_amt한식18_08', 'use_amt마트/슈퍼마켓20_08', 'use_amt농축수산물20_08']
# ['use_amt한식18_08', 'use_amt마트/슈퍼마켓20_08', 'use_amt농축수산물20_08']
# 09
# ['use_amt한식18_09', 'use_amt마트/슈퍼마켓18_09', 'foreign_pop남성20_09', 'use_amt한식20_09']
# ['use_amt한식18_09', 'use_amt마트/슈퍼마켓18_09', 'foreign_pop남성20_09', 'use_amt한식20_09']
# 10
# ['use_amt한식18_10', 'foreign_pop남성18_10', 'use_amt양식19_10', 'work_pop_cnt내국인여성그외19_10', 'use_amt부페20_10', 'visit_pop_cnt내국인여성그외18_10', 'resid_reg_pop여성18_10', 'use_amt간식18_10']
# ['foreign_pop남성18_10', 'work_pop_cnt내국인여성그외19_10', 'use_amt부페20_10', 'visit_pop_cnt내국인여성그외18_10', 'resid_reg_pop여성18_10', 'use_amt간식18_10', 'use_amt아시아음식19_10']
# 11
# ['use_amt한식18_11', 'em_g19_11', 'use_amt식품19_11', 'foreign_pop남성20_11', 'use_amt부페18_11']
# ['em_g19_11', 'use_amt식품19_11', 'foreign_pop여성20_11', 'use_amt패스트푸드18_11', 'use_amt부페18_11', 'work_pop_cnt내국인여성그외18_11', 'work_pop_cnt내국인남성그외18_11']
# 12
# ['em_g19_12', 'use_amt식품20_12', 'foreign_pop여성20_12']
# ['em_g19_12', 'use_amt식품20_12', 'foreign_pop여성20_12']
#                           0                         1  \
# 01fore            em_g20_01         use_amt아시아음식21_01
# 01step            em_g20_01         use_amt아시아음식21_01
# 02fore  use_amt마트/슈퍼마켓19_02                 em_g20_02
# 02step  use_amt마트/슈퍼마켓19_02                 em_g20_02
# 03fore    use_amt패스트푸드19_03       use_amt마트/슈퍼마켓18_03
# 03step  use_amt마트/슈퍼마켓18_03         use_amt농축수산물19_03
# 04fore    use_amt패스트푸드19_04        foreign_pop남성20_04
# 04step   foreign_pop남성20_04  work_pop_cnt내국인여성제주19_04
# 05fore    use_amt패스트푸드19_05        foreign_pop남성20_05
# 05step    use_amt패스트푸드19_05        foreign_pop남성20_05
# 06fore            em_g20_06            use_amt식품20_06
# 06step            em_g20_06            use_amt식품20_06
# 07fore       use_amt한식18_07         use_amt농축수산물20_07
# 07step       use_amt한식18_07         use_amt농축수산물20_07
# 08fore       use_amt한식18_08       use_amt마트/슈퍼마켓20_08
# 08step       use_amt한식18_08       use_amt마트/슈퍼마켓20_08
# 09fore       use_amt한식18_09       use_amt마트/슈퍼마켓18_09
# 09step       use_amt한식18_09       use_amt마트/슈퍼마켓18_09
# 10fore       use_amt한식18_10        foreign_pop남성18_10
# 10step   foreign_pop남성18_10  work_pop_cnt내국인여성그외19_10
# 11fore       use_amt한식18_11                 em_g19_11
# 11step            em_g19_11            use_amt식품19_11
# 12fore            em_g19_12            use_amt식품20_12
# 12step            em_g19_12            use_amt식품20_12
#
#                                2                          3  \
# 01fore                      None                       None
# 01step                      None                       None
# 02fore        foreign_pop여성21_02             use_amt식품18_02
# 02step            use_amt식품18_02          use_amt패스트푸드18_02
# 03fore         use_amt농축수산물19_03             use_amt양식20_03
# 03step            use_amt양식20_03                       None
# 04fore  work_pop_cnt내국인여성제주19_04          use_amt패스트푸드18_04
# 04step         use_amt패스트푸드18_04                       None
# 05fore  work_pop_cnt내국인여성그외18_05   work_pop_cnt내국인남성그외20_05
# 05step  work_pop_cnt내국인여성그외18_05   work_pop_cnt내국인남성그외20_05
# 06fore        foreign_pop남성21_06             use_amt부페20_06
# 06step        foreign_pop남성21_06             use_amt부페20_06
# 07fore            use_amt양식19_07                       None
# 07step            use_amt양식19_07                       None
# 08fore         use_amt농축수산물20_08                       None
# 08step         use_amt농축수산물20_08                       None
# 09fore        foreign_pop남성20_09             use_amt한식20_09
# 09step        foreign_pop남성20_09             use_amt한식20_09
# 10fore            use_amt양식19_10   work_pop_cnt내국인여성그외19_10
# 10step            use_amt부페20_10  visit_pop_cnt내국인여성그외18_10
# 11fore            use_amt식품19_11         foreign_pop남성20_11
# 11step        foreign_pop여성20_11          use_amt패스트푸드18_11
# 12fore        foreign_pop여성20_12                       None
# 12step        foreign_pop여성20_12                       None
#
#                                4                          5  \
# 01fore                      None                       None
# 01step                      None                       None
# 02fore         use_amt패스트푸드18_02                       None
# 02step                      None                       None
# 03fore                      None                       None
# 03step                      None                       None
# 04fore                      None                       None
# 04step                      None                       None
# 05fore            use_amt부페20_05   visit_pop_cnt장기해외그외18_05
# 05step            use_amt부페20_05   visit_pop_cnt장기해외그외18_05
# 06fore  visit_pop_cnt장기해외그외20_06   visit_pop_cnt장기해외그외19_06
# 06step  visit_pop_cnt장기해외그외20_06   visit_pop_cnt장기해외그외19_06
# 07fore                      None                       None
# 07step                      None                       None
# 08fore                      None                       None
# 08step                      None                       None
# 09fore                      None                       None
# 09step                      None                       None
# 10fore            use_amt부페20_10  visit_pop_cnt내국인여성그외18_10
# 10step      resid_reg_pop여성18_10             use_amt간식18_10
# 11fore            use_amt부페18_11                       None
# 11step            use_amt부페18_11   work_pop_cnt내국인여성그외18_11
# 12fore                      None                       None
# 12step                      None                       None
#
#                                6               7
# 01fore                      None            None
# 01step                      None            None
# 02fore                      None            None
# 02step                      None            None
# 03fore                      None            None
# 03step                      None            None
# 04fore                      None            None
# 04step                      None            None
# 05fore          total_pop여성18_05  use_amt양식20_05
# 05step          total_pop여성18_05  use_amt양식20_05
# 06fore   work_pop_cnt장기해외제주20_06            None
# 06step   work_pop_cnt장기해외제주20_06            None
# 07fore                      None            None
# 07step                      None            None
# 08fore                      None            None
# 08step                      None            None
# 09fore                      None            None
# 09step                      None            None
# 10fore      resid_reg_pop여성18_10  use_amt간식18_10
# 10step         use_amt아시아음식19_10            None
# 11fore                      None            None
# 11step  work_pop_cnt내국인남성그외18_11            None
# 12fore                      None            None
# 12step                      None            None

# %%
#A월 변수로 A-1월 예측 칼럼만 뽑기
#21년 6월 예측하기위해, 21년 6월 다 없애기

dic={ }

for j in ['21_06']:#,'21_05','21_04','21_03','21_02','21_01']:
    #삭제할 칼럼 있으면 선택
    delete=[]
    for i in merge_scale.columns.tolist():
        if not i[-5:] ==j:    ##
            delete.append(i)
    delete.append('em_g'+j)       ##

    print(stepwise_select('em_g'+j, merge_scale[delete]))
    dic[j+'step'] = selected_variables
dic
# Out:
# ['em_g21_04', 'use_amt부페20_08', 'foreign_pop남성21_02', 'foreign_pop남성20_10', 'visit_pop_cnt단기해외20_04', 'total_pop남성21_03']
# {'21_06step': ['em_g21_04',
#   'use_amt부페20_08',
#   'foreign_pop남성21_02',
#   'foreign_pop남성20_10',
#   'visit_pop_cnt단기해외20_04',
#   'total_pop남성21_03']}

# %%
select_result = pd.DataFrame.from_dict(dic, orient='index')
select_result.to_csv('A-1월 변수선택.csv',encoding='cp949')
select_result
# Out:
#                    0               1                   2                   3  \
# 21_06step  em_g21_04  use_amt부페20_08  foreign_pop남성21_02  foreign_pop남성20_10
#
#                                 4                 5
# 21_06step  visit_pop_cnt단기해외20_04  total_pop남성21_03

# %% [markdown]
# # 2. 동단위

# %%
#동별로 예측        

dic_month = {}

for k in range(0,42):   #42개지역 순환
    dic = {}
    #연, 월단위로 정렬
    #1~6월
    for j in ['01','02','03','04','05','06']:
        month=[]
        for i in merge_scale.columns.tolist():
            if i[-5:] == '18_'+j:   #칼럼 날짜가 18_월 일때
                month.append(i)
        for i in merge_scale.columns.tolist():
            if i[-5:] == '19_'+j:
                month.append(i)
        for i in merge_scale.columns.tolist():
            if i[-5:] == '20_'+j:
                month.append(i)  
        for i in merge_scale.columns.tolist():
            if i[-5:] == '21_'+j:
                month.append(i)
        dic[j+'월val']=merge_scale[month].iloc[k].values    #연-월단위로 정렬된 df의 벨류를 사전으로 만듦
    merge_part= pd.DataFrame.from_dict(dic, orient='index', columns=merge_scale[month].iloc[k].index)

    #선택법
    print(stepwise_select('em_g21_'+j, merge_part))
    dic_month[merge_scale.index[k]+'1~6'] = selected_variables


    dic= {}
    #7~12월
    for j in ['07','08','09','10','11','12']: 
        month=[]
        for i in merge_scale.columns.tolist():
            if i[-5:] == '18_'+j:
                month.append(i)
        for i in merge_scale.columns.tolist():
            if i[-5:] == '19_'+j:
                month.append(i)
        for i in merge_scale.columns.tolist():
            if i[-5:] == '20_'+j:
                month.append(i)  
        dic[j+'월val']=merge_scale[month].iloc[k].values   

    merge_part= pd.DataFrame.from_dict(dic, orient='index', columns=merge_scale[month].iloc[k].index)
    
    #단계적선택법
    print(stepwise_select('em_g20_'+j, merge_part))
    dic_month[merge_scale.index[k]+'7~12'] = selected_variables

pd.DataFrame.from_dict(dic_month, orient='index').to_csv('동별 선택법.csv', encoding='cp949')
dic_month
# Out:
# ['foreign_pop여성20_06', 'use_amt농축수산물18_06', 'visit_pop_cnt내국인남성그외18_06', 'total_pop여성19_06']
# ['resd_pop_cnt내국인남성제주18_12', 'use_amt양식19_12', 'use_amt주점및주류판매18_12', 'resd_pop_cnt장기해외제주20_12']
# ['em_g19_06', 'em_g18_06', 'resd_pop_cnt내국인남성제주21_06', 'use_amt마트/슈퍼마켓18_06', 'resd_pop_cnt내국인남성제주20_06', 'use_amt한식18_06']
# ['em_g18_12', 'resid_reg_pop남성20_12', 'work_pop_cnt내국인여성제주19_12', 'visit_pop_cnt내국인남성그외19_12', 'work_pop_cnt내국인여성그외19_12']
# ['work_pop_cnt내국인여성제주21_06', 'use_amt식품21_06', 'work_pop_cnt내국인여성제주18_06', 'resd_pop_cnt내국인여성제주18_06']
# ['visit_pop_cnt내국인남성제주18_12', 'work_pop_cnt내국인남성제주19_12', 'total_pop남성19_12', 'em_g18_12']
# ['use_amt간식19_06', 'resid_reg_pop남성21_06', 'resd_pop_cnt내국인남성제주20_06', 'use_amt마트/슈퍼마켓21_06', 'resid_reg_pop남성19_06', 'resd_pop_cnt내국인남성제주21_06', 'use_amt패스트푸드19_06', 'em_g19_06', 'use_amt마트/슈퍼마켓20_06', 'use_amt마트/슈퍼마켓18_06', 'resid_reg_pop여성19_06', 'total_pop여성19_06', 'use_amt패스트푸드21_06', 'use_amt주점및주류판매18_06', 'use_amt배달21_06', 'use_amt양식19_06', 'use_amt아시아음식21_06', 'total_pop여성20_06', 'use_amt한식21_06', 'em_g18_06', 'use_amt한식20_06', 'use_amt식품19_06', 'resid_reg_pop남성20_06', 'total_pop여성18_06', 'total_pop남성18_06', 'resd_pop_cnt내국인여성제주21_06', 'use_amt아시아음식20_06', 'use_amt간식20_06', 'total_pop남성19_06', 'use_amt식품18_06', 'use_amt간식21_06', 'resid_reg_pop여성20_06', 'total_pop남성21_06', 'use_amt양식18_06', 'use_amt아시아음식19_06', 'use_amt간식18_06', 'use_amt한식18_06', 'use_amt아시아음식18_06', 'resd_pop_cnt내국인여성제주20_06', 'use_amt한식19_06', 'resid_reg_pop여성18_06', 'resid_reg_pop남성18_06', 'resid_reg_pop여성21_06', 'use_amt식품21_06', 'use_amt마트/슈퍼마켓19_06', 'use_amt패스트푸드18_06', 'em_g20_06', 'use_amt패스트푸드20_06', 'total_pop여성21_06', 'total_pop남성20_06']
# ['use_amt식품19_12', 'use_amt아시아음식19_12', 'resd_pop_cnt내국인남성제주19_12', 'use_amt아시아음식18_12', 'total_pop남성20_12', 'resid_reg_pop여성18_12', 'total_pop여성20_12', 'use_amt패스트푸드19_12', 'total_pop여성19_12', 'use_amt배달20_12', 'total_pop남성19_12', 'use_amt패스트푸드20_12', 'use_amt마트/슈퍼마켓20_12', 'use_amt양식19_12', 'use_amt한식20_12', 'em_g19_12', 'resid_reg_pop남성19_12', 'use_amt간식18_12', 'use_amt간식20_12', 'use_amt식품18_12', 'resid_reg_pop여성20_12', 'em_g18_12', 'use_amt마트/슈퍼마켓19_12', 'resid_reg_pop여성19_12', 'use_amt양식18_12', 'total_pop남성18_12', 'resd_pop_cnt내국인여성제주20_12', 'use_amt아시아음식20_12', 'total_pop여성18_12', 'resd_pop_cnt내국인여성제주19_12', 'resid_reg_pop남성20_12', 'use_amt마트/슈퍼마켓18_12', 'resid_reg_pop남성18_12', 'use_amt간식19_12', 'resd_pop_cnt내국인남성제주20_12', 'use_amt한식19_12', 'use_amt한식18_12']
# ['resd_pop_cnt장기해외제주21_06', 'visit_pop_cnt내국인남성그외19_06', 'use_amt농축수산물21_06', 'visit_pop_cnt내국인남성제주18_06']
# ['em_g18_12', 'use_amt마트/슈퍼마켓19_12', 'use_amt농축수산물18_12', 'visit_pop_cnt내국인남성제주20_12']
# ['resd_pop_cnt내국인남성제주18_06', 'work_pop_cnt장기해외제주18_06', 'foreign_pop남성19_06', 'use_amt부페19_06']
# ['resid_reg_pop남성20_12', 'use_amt부페18_12', 'work_pop_cnt내국인남성제주18_12', 'total_pop여성18_12']
# ['resid_reg_pop남성21_06', 'foreign_pop남성20_06', 'visit_pop_cnt내국인여성제주21_06', 'work_pop_cnt내국인남성그외18_06']
# ['use_amt양식19_12', 'visit_pop_cnt내국인남성제주18_12', 'em_g19_12', 'total_pop남성18_12']
# ['work_pop_cnt내국인여성제주19_06', 'resd_pop_cnt내국인남성제주20_06', 'em_g18_06', 'work_pop_cnt장기해외제주19_06']
# ['work_pop_cnt내국인남성제주20_12', 'resid_reg_pop남성20_12', 'visit_pop_cnt내국인여성제주20_12', 'use_amt부페20_12']
# ['use_amt패스트푸드20_06', 'resd_pop_cnt내국인여성제주18_06', 'use_amt간식20_06', 'em_g19_06']
# ['visit_pop_cnt장기해외제주20_12', 'visit_pop_cnt내국인남성제주19_12', 'visit_pop_cnt단기해외18_12', 'use_amt간식20_12']
# ['use_amt배달19_06', 'work_pop_cnt장기해외제주18_06', 'visit_pop_cnt내국인여성제주21_06', 'visit_pop_cnt내국인여성제주18_06']
# ['use_amt한식18_12', 'visit_pop_cnt장기해외그외20_12', 'use_amt양식19_12', 'resid_reg_pop여성19_12']
# ['work_pop_cnt내국인여성제주21_06', 'use_amt부페20_06', 'work_pop_cnt장기해외그외18_06', 'foreign_pop여성20_06']
# ['work_pop_cnt장기해외그외20_12', 'use_amt부페19_12', 'resd_pop_cnt장기해외제주20_12', 'visit_pop_cnt단기해외19_12']
# ['use_amt간식20_06', 'use_amt간식18_06', 'use_amt부페20_06', 'work_pop_cnt내국인여성제주19_06']
# ['resid_reg_pop남성18_12', 'use_amt간식18_12', 'use_amt주점및주류판매19_12', 'use_amt주점및주류판매18_12']
# ['visit_pop_cnt장기해외그외20_06', 'use_amt농축수산물21_06', 'resd_pop_cnt내국인여성제주20_06', 'resd_pop_cnt내국인여성제주18_06']
# ['visit_pop_cnt내국인남성제주18_12', 'use_amt부페20_12', 'use_amt아시아음식19_12', 'work_pop_cnt장기해외그외18_12']
# ['resd_pop_cnt내국인여성제주19_06', 'visit_pop_cnt장기해외제주18_06', 'use_amt농축수산물21_06', 'work_pop_cnt내국인여성제주19_06']
# ['use_amt패스트푸드18_12', 'total_pop남성20_12', 'work_pop_cnt내국인남성제주19_12', 'total_pop남성19_12']
# ['total_pop남성18_06', 'use_amt아시아음식19_06', 'use_amt주점및주류판매19_06', 'total_pop여성21_06']
# ['use_amt식품20_12', 'use_amt패스트푸드20_12', 'use_amt마트/슈퍼마켓20_12', 'resd_pop_cnt장기해외제주18_12']
# ['use_amt한식20_06', 'use_amt부페21_06', 'use_amt마트/슈퍼마켓18_06', 'use_amt패스트푸드20_06', 'foreign_pop여성18_06']
# ['resid_reg_pop남성18_12', 'total_pop남성19_12', 'use_amt패스트푸드20_12', 'use_amt배달20_12']
# ['visit_pop_cnt장기해외그외21_06', 'work_pop_cnt장기해외제주18_06', 'use_amt양식20_06', 'foreign_pop여성21_06']
# ['resid_reg_pop남성20_12', 'work_pop_cnt장기해외제주18_12', 'total_pop남성18_12', 'use_amt아시아음식18_12']
# ['foreign_pop여성18_06', 'use_amt한식18_06', 'use_amt양식19_06', 'use_amt간식18_06', 'visit_pop_cnt장기해외제주19_06']
# ['total_pop남성20_12', 'total_pop여성20_12', 'resid_reg_pop여성18_12', 'resid_reg_pop남성19_12', 'resid_reg_pop여성19_12', 'resid_reg_pop여성20_12', 'foreign_pop여성19_12', 'foreign_pop남성20_12', 'total_pop여성18_12', 'total_pop남성18_12', 'total_pop남성19_12', 'resid_reg_pop남성20_12', 'total_pop여성19_12', 'foreign_pop남성18_12', 'resid_reg_pop남성18_12', 'foreign_pop여성20_12', 'foreign_pop여성18_12', 'foreign_pop남성19_12', 'use_amt배달20_12', 'visit_pop_cnt내국인남성그외18_12', 'visit_pop_cnt내국인남성제주19_12', 'use_amt간식19_12']
# []
# []
# ['resd_pop_cnt장기해외제주20_06', 'resd_pop_cnt장기해외제주21_06', 'visit_pop_cnt단기해외19_06', 'visit_pop_cnt장기해외제주18_06', 'resd_pop_cnt장기해외제주18_06', 'resd_pop_cnt장기해외제주19_06', 'work_pop_cnt장기해외제주19_06', 'work_pop_cnt장기해외제주18_06', 'visit_pop_cnt단기해외18_06', 'resd_pop_cnt내국인여성제주20_06', 'use_amt부페19_06', 'work_pop_cnt내국인남성제주18_06', 'visit_pop_cnt내국인남성그외21_06']
# ['resd_pop_cnt장기해외제주19_12', 'visit_pop_cnt단기해외18_12', 'resd_pop_cnt장기해외제주20_12', 'work_pop_cnt장기해외제주19_12', 'work_pop_cnt장기해외제주18_12', 'visit_pop_cnt단기해외19_12', 'resd_pop_cnt장기해외제주18_12', 'use_amt농축수산물18_12', 'visit_pop_cnt내국인여성그외20_12', 'foreign_pop남성18_12', 'use_amt마트/슈퍼마켓19_12']
# ['resd_pop_cnt장기해외제주20_06', 'use_amt간식20_06', 'visit_pop_cnt내국인남성제주19_06', 'work_pop_cnt내국인여성그외21_06', 'use_amt배달18_06']
# ['use_amt배달18_12', 'use_amt주점및주류판매19_12', 'resd_pop_cnt장기해외제주19_12', 'visit_pop_cnt장기해외그외19_12', 'use_amt마트/슈퍼마켓20_12', 'visit_pop_cnt내국인남성제주18_12']
# ['use_amt부페21_06', 'em_g18_06', 'work_pop_cnt내국인남성그외18_06', 'work_pop_cnt장기해외제주18_06', 'resid_reg_pop여성19_06']
# ['use_amt부페19_12', 'use_amt패스트푸드20_12', 'work_pop_cnt내국인여성그외20_12', 'resd_pop_cnt내국인여성제주19_12']
# ['visit_pop_cnt단기해외19_06', 'work_pop_cnt장기해외제주19_06', 'foreign_pop남성21_06', 'use_amt패스트푸드20_06']
# ['visit_pop_cnt장기해외그외19_12', 'use_amt농축수산물19_12', 'use_amt패스트푸드18_12', 'resd_pop_cnt내국인남성제주18_12']
# ['foreign_pop남성21_06', 'work_pop_cnt장기해외그외20_06', 'use_amt부페20_06', 'use_amt한식18_06']
# ['work_pop_cnt내국인여성제주18_12', 'work_pop_cnt내국인남성그외19_12', 'visit_pop_cnt내국인남성제주18_12', 'total_pop남성19_12']
# ['resd_pop_cnt내국인여성제주20_06', 'total_pop여성20_06', 'visit_pop_cnt내국인남성그외21_06', 'resid_reg_pop남성19_06']
# ['visit_pop_cnt단기해외18_12', 'resid_reg_pop남성19_12', 'resid_reg_pop여성20_12', 'visit_pop_cnt내국인남성그외19_12']
# ['foreign_pop여성18_06', 'foreign_pop남성20_06', 'use_amt부페18_06', 'work_pop_cnt장기해외제주21_06']
# ['work_pop_cnt장기해외제주20_12', 'use_amt한식19_12', 'visit_pop_cnt내국인여성제주19_12', 'resid_reg_pop여성20_12']
# ['resd_pop_cnt내국인남성제주21_06', 'visit_pop_cnt내국인남성그외21_06', 'visit_pop_cnt내국인남성그외18_06', 'use_amt배달19_06']
# ['foreign_pop여성20_12', 'work_pop_cnt장기해외제주20_12', 'visit_pop_cnt장기해외제주19_12', 'foreign_pop남성20_12']
# ['work_pop_cnt장기해외제주19_06', 'visit_pop_cnt내국인남성그외20_06', 'use_amt부페21_06', 'visit_pop_cnt장기해외제주18_06']
# ['visit_pop_cnt장기해외그외19_12', 'visit_pop_cnt내국인남성그외19_12', 'use_amt패스트푸드20_12', 'work_pop_cnt내국인여성제주18_12']
# ['visit_pop_cnt내국인남성제주21_06', 'resd_pop_cnt내국인여성제주18_06', 'work_pop_cnt내국인여성제주21_06', 'visit_pop_cnt내국인남성제주19_06', 'visit_pop_cnt내국인여성제주18_06', 'resd_pop_cnt내국인남성제주18_06', 'visit_pop_cnt내국인남성제주18_06', 'use_amt농축수산물18_06', 'use_amt농축수산물20_06', 'visit_pop_cnt내국인여성제주19_06', 'visit_pop_cnt내국인남성제주20_06', 'work_pop_cnt내국인남성제주21_06', 'visit_pop_cnt내국인여성제주20_06', 'work_pop_cnt내국인여성제주20_06', 'visit_pop_cnt내국인여성제주21_06', 'work_pop_cnt내국인남성제주20_06', 'work_pop_cnt내국인남성그외19_06', 'work_pop_cnt내국인여성제주18_06', 'use_amt부페20_06', 'work_pop_cnt장기해외그외19_06']
# ['visit_pop_cnt내국인남성제주20_12', 'work_pop_cnt내국인여성제주20_12', 'visit_pop_cnt내국인여성제주20_12', 'visit_pop_cnt내국인여성제주18_12', 'resd_pop_cnt내국인남성제주18_12', 'visit_pop_cnt내국인남성제주19_12', 'visit_pop_cnt내국인여성제주19_12', 'visit_pop_cnt내국인남성제주18_12', 'resd_pop_cnt장기해외제주20_12', 'use_amt한식20_12', 'use_amt아시아음식19_12', 'visit_pop_cnt장기해외제주18_12']
# ['resd_pop_cnt내국인여성제주20_06', 'work_pop_cnt내국인남성제주20_06', 'work_pop_cnt장기해외제주18_06', 'visit_pop_cnt단기해외20_06']
# ['use_amt패스트푸드18_12', 'visit_pop_cnt내국인남성제주19_12', 'resd_pop_cnt장기해외제주19_12', 'foreign_pop여성18_12']
# ['use_amt배달18_06', 'resid_reg_pop여성20_06', 'use_amt농축수산물18_06', 'use_amt패스트푸드21_06']
# ['visit_pop_cnt내국인남성제주20_12', 'resd_pop_cnt내국인남성제주18_12', 'use_amt한식19_12', 'use_amt배달20_12']
# ['em_g18_06', 'visit_pop_cnt내국인남성제주19_06', 'visit_pop_cnt내국인여성그외18_06', 'visit_pop_cnt내국인여성제주19_06']
# ['use_amt부페20_12', 'work_pop_cnt내국인여성그외20_12', 'work_pop_cnt내국인여성그외18_12', 'use_amt아시아음식20_12']
# ['foreign_pop남성18_06', 'visit_pop_cnt내국인여성그외18_06']
# ['use_amt부페20_12', 'use_amt배달19_12', 'use_amt아시아음식18_12', 'foreign_pop남성20_12']
# ['em_g19_06', 'em_g18_06', 'use_amt식품19_06', 'work_pop_cnt내국인여성그외21_06', 'use_amt패스트푸드18_06', 'work_pop_cnt장기해외제주21_06']
# ['em_g18_12', 'visit_pop_cnt단기해외18_12', 'work_pop_cnt장기해외제주20_12', 'resd_pop_cnt장기해외제주18_12', 'visit_pop_cnt내국인남성그외18_12']
# ['foreign_pop남성21_06', 'work_pop_cnt내국인남성제주20_06', 'work_pop_cnt내국인여성그외20_06', 'work_pop_cnt장기해외그외20_06']
# ['resd_pop_cnt내국인여성제주19_12', 'use_amt주점및주류판매20_12', 'visit_pop_cnt장기해외제주20_12', 'visit_pop_cnt장기해외그외19_12']
# ['use_amt식품19_06', 'work_pop_cnt장기해외그외21_06', 'work_pop_cnt장기해외제주20_06', 'work_pop_cnt내국인여성제주21_06']
# ['work_pop_cnt장기해외그외20_12', 'use_amt배달20_12', 'visit_pop_cnt장기해외그외20_12', 'visit_pop_cnt장기해외그외19_12']
# ['use_amt부페21_06', 'use_amt마트/슈퍼마켓21_06', 'visit_pop_cnt단기해외21_06', 'visit_pop_cnt장기해외제주20_06', 'use_amt패스트푸드18_06']
# ['use_amt한식18_12', 'foreign_pop여성18_12', 'work_pop_cnt장기해외제주20_12', 'visit_pop_cnt내국인여성제주19_12']
# ['resid_reg_pop남성19_06', 'resd_pop_cnt장기해외제주18_06', 'work_pop_cnt장기해외그외21_06', 'use_amt패스트푸드21_06']
# ['work_pop_cnt장기해외그외18_12']
# ['use_amt한식18_06', 'use_amt양식20_06', 'em_g19_06', 'em_g18_06', 'use_amt배달18_06', 'use_amt아시아음식18_06']
# ['use_amt부페20_12', 'em_g18_12', 'resd_pop_cnt장기해외제주19_12', 'use_amt부페18_12', 'use_amt아시아음식18_12', 'work_pop_cnt내국인여성제주18_12']
# ['foreign_pop여성21_06', 'foreign_pop여성18_06', 'foreign_pop남성21_06', 'em_g19_06', 'foreign_pop남성20_06', 'em_g18_06', 'foreign_pop남성19_06', 'work_pop_cnt장기해외그외18_06', 'foreign_pop남성18_06', 'foreign_pop여성19_06', 'foreign_pop여성20_06', 'resid_reg_pop여성18_06', 'use_amt주점및주류판매19_06', 'use_amt마트/슈퍼마켓19_06', 'use_amt간식19_06']
# ['em_g18_12', 'foreign_pop남성19_12', 'foreign_pop남성18_12', 'foreign_pop여성19_12', 'foreign_pop남성20_12', 'work_pop_cnt장기해외그외18_12', 'foreign_pop여성20_12', 'foreign_pop여성18_12']
# ['use_amt식품19_06', 'use_amt주점및주류판매21_06']
# ['work_pop_cnt내국인남성제주20_12', 'visit_pop_cnt내국인남성제주20_12', 'work_pop_cnt장기해외그외18_12', 'visit_pop_cnt내국인남성제주18_12']
# ['visit_pop_cnt장기해외그외21_06', 'resd_pop_cnt내국인남성제주21_06', 'use_amt농축수산물21_06', 'use_amt양식19_06']
# ['visit_pop_cnt장기해외그외19_12', 'use_amt부페20_12']
# {'건입동1~6': ['foreign_pop여성20_06',
#   'use_amt농축수산물18_06',
#   'visit_pop_cnt내국인남성그외18_06',
#   'total_pop여성19_06'],
#  '건입동7~12': ['resd_pop_cnt내국인남성제주18_12',
#   'use_amt양식19_12',
#   'use_amt주점및주류판매18_12',
#   'resd_pop_cnt장기해외제주20_12'],
#  '구좌읍1~6': ['em_g19_06',
#   'em_g18_06',
#   'resd_pop_cnt내국인남성제주21_06',
#   'use_amt마트/슈퍼마켓18_06',
#   'resd_pop_cnt내국인남성제주20_06',
#   'use_amt한식18_06'],
#  '구좌읍7~12': ['em_g18_12',
#   'resid_reg_pop남성20_12',
#   'work_pop_cnt내국인여성제주19_12',
#   'visit_pop_cnt내국인남성그외19_12',
#   'work_pop_cnt내국인여성그외19_12'],
#  '남원읍1~6': ['work_pop_cnt내국인여성제주21_06',
#   'use_amt식품21_06',
#   'work_pop_cnt내국인여성제주18_06',
#   'resd_pop_cnt내국인여성제주18_06'],
#  '남원읍7~12': ['visit_pop_cnt내국인남성제주18_12',
#   'work_pop_cnt내국인남성제주19_12',
#   'total_pop남성19_12',
#   'em_g18_12'],
#  '노형동1~6': ['use_amt간식19_06',
#   'resid_reg_pop남성21_06',
#   'resd_pop_cnt내국인남성제주20_06',
#   'use_amt마트/슈퍼마켓21_06',
#   'resid_reg_pop남성19_06',
#   'resd_pop_cnt내국인남성제주21_06',
#   'use_amt패스트푸드19_06',
#   'em_g19_06',
#   'use_amt마트/슈퍼마켓20_06',
#   'use_amt마트/슈퍼마켓18_06',
#   'resid_reg_pop여성19_06',
#   'total_pop여성19_06',
#   'use_amt패스트푸드21_06',
#   'use_amt주점및주류판매18_06',
#   'use_amt배달21_06',
#   'use_amt양식19_06',
#   'use_amt아시아음식21_06',
#   'total_pop여성20_06',
#   'use_amt한식21_06',
#   'em_g18_06',
#   'use_amt한식20_06',
#   'use_amt식품19_06',
#   'resid_reg_pop남성20_06',
#   'total_pop여성18_06',
#   'total_pop남성18_06',
#   'resd_pop_cnt내국인여성제주21_06',
#   'use_amt아시아음식20_06',
#   'use_amt간식20_06',
#   'total_pop남성19_06',
#   'use_amt식품18_06',
#   'use_amt간식21_06',
#   'resid_reg_pop여성20_06',
#   'total_pop남성21_06',
#   'use_amt양식18_06',
#   'use_amt아시아음식19_06',
#   'use_amt간식18_06',
#   'use_amt한식18_06',
#   'use_amt아시아음식18_06',
#   'resd_pop_cnt내국인여성제주20_06',
#   'use_amt한식19_06',
#   'resid_reg_pop여성18_06',
#   'resid_reg_pop남성18_06',
#   'resid_reg_pop여성21_06',
#   'use_amt식품21_06',
#   'use_amt마트/슈퍼마켓19_06',
#   'use_amt패스트푸드18_06',
#   'em_g20_06',
#   'use_amt패스트푸드20_06',
#   'total_pop여성21_06',
#   'total_pop남성20_06'],
#  '노형동7~12': ['use_amt식품19_12',
#   'use_amt아시아음식19_12',
#   'resd_pop_cnt내국인남성제주19_12',
#   'use_amt아시아음식18_12',
#   'total_pop남성20_12',
#   'resid_reg_pop여성18_12',
#   'total_pop여성20_12',
#   'use_amt패스트푸드19_12',
#   'total_pop여성19_12',
#   'use_amt배달20_12',
#   'total_pop남성19_12',
#   'use_amt패스트푸드20_12',
#   'use_amt마트/슈퍼마켓20_12',
#   'use_amt양식19_12',
#   'use_amt한식20_12',
#   'em_g19_12',
#   'resid_reg_pop남성19_12',
#   'use_amt간식18_12',
#   'use_amt간식20_12',
#   'use_amt식품18_12',
#   'resid_reg_pop여성20_12',
#   'em_g18_12',
#   'use_amt마트/슈퍼마켓19_12',
#   'resid_reg_pop여성19_12',
#   'use_amt양식18_12',
#   'total_pop남성18_12',
#   'resd_pop_cnt내국인여성제주20_12',
#   'use_amt아시아음식20_12',
#   'total_pop여성18_12',
#   'resd_pop_cnt내국인여성제주19_12',
#   'resid_reg_pop남성20_12',
#   'use_amt마트/슈퍼마켓18_12',
#   'resid_reg_pop남성18_12',
#   'use_amt간식19_12',
#   'resd_pop_cnt내국인남성제주20_12',
#   'use_amt한식19_12',
#   'use_amt한식18_12'],
#  '대륜동1~6': ['resd_pop_cnt장기해외제주21_06',
#   'visit_pop_cnt내국인남성그외19_06',
#   'use_amt농축수산물21_06',
#   'visit_pop_cnt내국인남성제주18_06'],
#  '대륜동7~12': ['em_g18_12',
#   'use_amt마트/슈퍼마켓19_12',
#   'use_amt농축수산물18_12',
#   'visit_pop_cnt내국인남성제주20_12'],
#  '대정읍1~6': ['resd_pop_cnt내국인남성제주18_06',
#   'work_pop_cnt장기해외제주18_06',
#   'foreign_pop남성19_06',
#   'use_amt부페19_06'],
#  '대정읍7~12': ['resid_reg_pop남성20_12',
#   'use_amt부페18_12',
#   'work_pop_cnt내국인남성제주18_12',
#   'total_pop여성18_12'],
#  '대천동1~6': ['resid_reg_pop남성21_06',
#   'foreign_pop남성20_06',
#   'visit_pop_cnt내국인여성제주21_06',
#   'work_pop_cnt내국인남성그외18_06'],
#  '대천동7~12': ['use_amt양식19_12',
#   'visit_pop_cnt내국인남성제주18_12',
#   'em_g19_12',
#   'total_pop남성18_12'],
#  '도두동1~6': ['work_pop_cnt내국인여성제주19_06',
#   'resd_pop_cnt내국인남성제주20_06',
#   'em_g18_06',
#   'work_pop_cnt장기해외제주19_06'],
#  '도두동7~12': ['work_pop_cnt내국인남성제주20_12',
#   'resid_reg_pop남성20_12',
#   'visit_pop_cnt내국인여성제주20_12',
#   'use_amt부페20_12'],
#  '동홍동1~6': ['use_amt패스트푸드20_06',
#   'resd_pop_cnt내국인여성제주18_06',
#   'use_amt간식20_06',
#   'em_g19_06'],
#  '동홍동7~12': ['visit_pop_cnt장기해외제주20_12',
#   'visit_pop_cnt내국인남성제주19_12',
#   'visit_pop_cnt단기해외18_12',
#   'use_amt간식20_12'],
#  '봉개동1~6': ['use_amt배달19_06',
#   'work_pop_cnt장기해외제주18_06',
#   'visit_pop_cnt내국인여성제주21_06',
#   'visit_pop_cnt내국인여성제주18_06'],
#  '봉개동7~12': ['use_amt한식18_12',
#   'visit_pop_cnt장기해외그외20_12',
#   'use_amt양식19_12',
#   'resid_reg_pop여성19_12'],
#  '삼도1동1~6': ['work_pop_cnt내국인여성제주21_06',
#   'use_amt부페20_06',
#   'work_pop_cnt장기해외그외18_06',
#   'foreign_pop여성20_06'],
#  '삼도1동7~12': ['work_pop_cnt장기해외그외20_12',
#   'use_amt부페19_12',
#   'resd_pop_cnt장기해외제주20_12',
#   'visit_pop_cnt단기해외19_12'],
#  '삼도2동1~6': ['use_amt간식20_06',
#   'use_amt간식18_06',
#   'use_amt부페20_06',
#   'work_pop_cnt내국인여성제주19_06'],
#  '삼도2동7~12': ['resid_reg_pop남성18_12',
#   'use_amt간식18_12',
#   'use_amt주점및주류판매19_12',
#   'use_amt주점및주류판매18_12'],
#  '삼양동1~6': ['visit_pop_cnt장기해외그외20_06',
#   'use_amt농축수산물21_06',
#   'resd_pop_cnt내국인여성제주20_06',
#   'resd_pop_cnt내국인여성제주18_06'],
#  '삼양동7~12': ['visit_pop_cnt내국인남성제주18_12',
#   'use_amt부페20_12',
#   'use_amt아시아음식19_12',
#   'work_pop_cnt장기해외그외18_12'],
#  '서홍동1~6': ['resd_pop_cnt내국인여성제주19_06',
#   'visit_pop_cnt장기해외제주18_06',
#   'use_amt농축수산물21_06',
#   'work_pop_cnt내국인여성제주19_06'],
#  '서홍동7~12': ['use_amt패스트푸드18_12',
#   'total_pop남성20_12',
#   'work_pop_cnt내국인남성제주19_12',
#   'total_pop남성19_12'],
#  '성산읍1~6': ['total_pop남성18_06',
#   'use_amt아시아음식19_06',
#   'use_amt주점및주류판매19_06',
#   'total_pop여성21_06'],
#  '성산읍7~12': ['use_amt식품20_12',
#   'use_amt패스트푸드20_12',
#   'use_amt마트/슈퍼마켓20_12',
#   'resd_pop_cnt장기해외제주18_12'],
#  '송산동1~6': ['use_amt한식20_06',
#   'use_amt부페21_06',
#   'use_amt마트/슈퍼마켓18_06',
#   'use_amt패스트푸드20_06',
#   'foreign_pop여성18_06'],
#  '송산동7~12': ['resid_reg_pop남성18_12',
#   'total_pop남성19_12',
#   'use_amt패스트푸드20_12',
#   'use_amt배달20_12'],
#  '아라동1~6': ['visit_pop_cnt장기해외그외21_06',
#   'work_pop_cnt장기해외제주18_06',
#   'use_amt양식20_06',
#   'foreign_pop여성21_06'],
#  '아라동7~12': ['resid_reg_pop남성20_12',
#   'work_pop_cnt장기해외제주18_12',
#   'total_pop남성18_12',
#   'use_amt아시아음식18_12'],
#  '안덕면1~6': ['foreign_pop여성18_06',
#   'use_amt한식18_06',
#   'use_amt양식19_06',
#   'use_amt간식18_06',
#   'visit_pop_cnt장기해외제주19_06'],
#  '안덕면7~12': ['total_pop남성20_12',
#   'total_pop여성20_12',
#   'resid_reg_pop여성18_12',
#   'resid_reg_pop남성19_12',
#   'resid_reg_pop여성19_12',
#   'resid_reg_pop여성20_12',
#   'foreign_pop여성19_12',
#   'foreign_pop남성20_12',
#   'total_pop여성18_12',
#   'total_pop남성18_12',
#   'total_pop남성19_12',
#   'resid_reg_pop남성20_12',
#   'total_pop여성19_12',
#   'foreign_pop남성18_12',
#   'resid_reg_pop남성18_12',
#   'foreign_pop여성20_12',
#   'foreign_pop여성18_12',
#   'foreign_pop남성19_12',
#   'use_amt배달20_12',
#   'visit_pop_cnt내국인남성그외18_12',
#   'visit_pop_cnt내국인남성제주19_12',
#   'use_amt간식19_12'],
#  '알수없음1~6': [],
#  '알수없음7~12': [],
#  '애월읍1~6': ['resd_pop_cnt장기해외제주20_06',
#   'resd_pop_cnt장기해외제주21_06',
#   'visit_pop_cnt단기해외19_06',
#   'visit_pop_cnt장기해외제주18_06',
#   'resd_pop_cnt장기해외제주18_06',
#   'resd_pop_cnt장기해외제주19_06',
#   'work_pop_cnt장기해외제주19_06',
#   'work_pop_cnt장기해외제주18_06',
#   'visit_pop_cnt단기해외18_06',
#   'resd_pop_cnt내국인여성제주20_06',
#   'use_amt부페19_06',
#   'work_pop_cnt내국인남성제주18_06',
#   'visit_pop_cnt내국인남성그외21_06'],
#  '애월읍7~12': ['resd_pop_cnt장기해외제주19_12',
#   'visit_pop_cnt단기해외18_12',
#   'resd_pop_cnt장기해외제주20_12',
#   'work_pop_cnt장기해외제주19_12',
#   'work_pop_cnt장기해외제주18_12',
#   'visit_pop_cnt단기해외19_12',
#   'resd_pop_cnt장기해외제주18_12',
#   'use_amt농축수산물18_12',
#   'visit_pop_cnt내국인여성그외20_12',
#   'foreign_pop남성18_12',
#   'use_amt마트/슈퍼마켓19_12'],
#  '연동1~6': ['resd_pop_cnt장기해외제주20_06',
#   'use_amt간식20_06',
#   'visit_pop_cnt내국인남성제주19_06',
#   'work_pop_cnt내국인여성그외21_06',
#   'use_amt배달18_06'],
#  '연동7~12': ['use_amt배달18_12',
#   'use_amt주점및주류판매19_12',
#   'resd_pop_cnt장기해외제주19_12',
#   'visit_pop_cnt장기해외그외19_12',
#   'use_amt마트/슈퍼마켓20_12',
#   'visit_pop_cnt내국인남성제주18_12'],
#  '영천동1~6': ['use_amt부페21_06',
#   'em_g18_06',
#   'work_pop_cnt내국인남성그외18_06',
#   'work_pop_cnt장기해외제주18_06',
#   'resid_reg_pop여성19_06'],
#  '영천동7~12': ['use_amt부페19_12',
#   'use_amt패스트푸드20_12',
#   'work_pop_cnt내국인여성그외20_12',
#   'resd_pop_cnt내국인여성제주19_12'],
#  '예래동1~6': ['visit_pop_cnt단기해외19_06',
#   'work_pop_cnt장기해외제주19_06',
#   'foreign_pop남성21_06',
#   'use_amt패스트푸드20_06'],
#  '예래동7~12': ['visit_pop_cnt장기해외그외19_12',
#   'use_amt농축수산물19_12',
#   'use_amt패스트푸드18_12',
#   'resd_pop_cnt내국인남성제주18_12'],
#  '오라동1~6': ['foreign_pop남성21_06',
#   'work_pop_cnt장기해외그외20_06',
#   'use_amt부페20_06',
#   'use_amt한식18_06'],
#  '오라동7~12': ['work_pop_cnt내국인여성제주18_12',
#   'work_pop_cnt내국인남성그외19_12',
#   'visit_pop_cnt내국인남성제주18_12',
#   'total_pop남성19_12'],
#  '외도동1~6': ['resd_pop_cnt내국인여성제주20_06',
#   'total_pop여성20_06',
#   'visit_pop_cnt내국인남성그외21_06',
#   'resid_reg_pop남성19_06'],
#  '외도동7~12': ['visit_pop_cnt단기해외18_12',
#   'resid_reg_pop남성19_12',
#   'resid_reg_pop여성20_12',
#   'visit_pop_cnt내국인남성그외19_12'],
#  '용담1동1~6': ['foreign_pop여성18_06',
#   'foreign_pop남성20_06',
#   'use_amt부페18_06',
#   'work_pop_cnt장기해외제주21_06'],
#  '용담1동7~12': ['work_pop_cnt장기해외제주20_12',
#   'use_amt한식19_12',
#   'visit_pop_cnt내국인여성제주19_12',
#   'resid_reg_pop여성20_12'],
#  '용담2동1~6': ['resd_pop_cnt내국인남성제주21_06',
#   'visit_pop_cnt내국인남성그외21_06',
#   'visit_pop_cnt내국인남성그외18_06',
#   'use_amt배달19_06'],
#  '용담2동7~12': ['foreign_pop여성20_12',
#   'work_pop_cnt장기해외제주20_12',
#   'visit_pop_cnt장기해외제주19_12',
#   'foreign_pop남성20_12'],
#  '이도1동1~6': ['work_pop_cnt장기해외제주19_06',
#   'visit_pop_cnt내국인남성그외20_06',
#   'use_amt부페21_06',
#   'visit_pop_cnt장기해외제주18_06'],
#  '이도1동7~12': ['visit_pop_cnt장기해외그외19_12',
#   'visit_pop_cnt내국인남성그외19_12',
#   'use_amt패스트푸드20_12',
#   'work_pop_cnt내국인여성제주18_12'],
#  '이도2동1~6': ['visit_pop_cnt내국인남성제주21_06',
#   'resd_pop_cnt내국인여성제주18_06',
#   'work_pop_cnt내국인여성제주21_06',
#   'visit_pop_cnt내국인남성제주19_06',
#   'visit_pop_cnt내국인여성제주18_06',
#   'resd_pop_cnt내국인남성제주18_06',
#   'visit_pop_cnt내국인남성제주18_06',
#   'use_amt농축수산물18_06',
#   'use_amt농축수산물20_06',
#   'visit_pop_cnt내국인여성제주19_06',
#   'visit_pop_cnt내국인남성제주20_06',
#   'work_pop_cnt내국인남성제주21_06',
#   'visit_pop_cnt내국인여성제주20_06',
#   'work_pop_cnt내국인여성제주20_06',
#   'visit_pop_cnt내국인여성제주21_06',
#   'work_pop_cnt내국인남성제주20_06',
#   'work_pop_cnt내국인남성그외19_06',
#   'work_pop_cnt내국인여성제주18_06',
#   'use_amt부페20_06',
#   'work_pop_cnt장기해외그외19_06'],
#  '이도2동7~12': ['visit_pop_cnt내국인남성제주20_12',
#   'work_pop_cnt내국인여성제주20_12',
#   'visit_pop_cnt내국인여성제주20_12',
#   'visit_pop_cnt내국인여성제주18_12',
#   'resd_pop_cnt내국인남성제주18_12',
#   'visit_pop_cnt내국인남성제주19_12',
#   'visit_pop_cnt내국인여성제주19_12',
#   'visit_pop_cnt내국인남성제주18_12',
#   'resd_pop_cnt장기해외제주20_12',
#   'use_amt한식20_12',
#   'use_amt아시아음식19_12',
#   'visit_pop_cnt장기해외제주18_12'],
#  '이호동1~6': ['resd_pop_cnt내국인여성제주20_06',
#   'work_pop_cnt내국인남성제주20_06',
#   'work_pop_cnt장기해외제주18_06',
#   'visit_pop_cnt단기해외20_06'],
#  '이호동7~12': ['use_amt패스트푸드18_12',
#   'visit_pop_cnt내국인남성제주19_12',
#   'resd_pop_cnt장기해외제주19_12',
#   'foreign_pop여성18_12'],
#  '일도1동1~6': ['use_amt배달18_06',
#   'resid_reg_pop여성20_06',
#   'use_amt농축수산물18_06',
#   'use_amt패스트푸드21_06'],
#  '일도1동7~12': ['visit_pop_cnt내국인남성제주20_12',
#   'resd_pop_cnt내국인남성제주18_12',
#   'use_amt한식19_12',
#   'use_amt배달20_12'],
#  '일도2동1~6': ['em_g18_06',
#   'visit_pop_cnt내국인남성제주19_06',
#   'visit_pop_cnt내국인여성그외18_06',
#   'visit_pop_cnt내국인여성제주19_06'],
#  '일도2동7~12': ['use_amt부페20_12',
#   'work_pop_cnt내국인여성그외20_12',
#   'work_pop_cnt내국인여성그외18_12',
#   'use_amt아시아음식20_12'],
#  '정방동1~6': ['foreign_pop남성18_06', 'visit_pop_cnt내국인여성그외18_06'],
#  '정방동7~12': ['use_amt부페20_12',
#   'use_amt배달19_12',
#   'use_amt아시아음식18_12',
#   'foreign_pop남성20_12'],
#  '조천읍1~6': ['em_g19_06',
#   'em_g18_06',
#   'use_amt식품19_06',
#   'work_pop_cnt내국인여성그외21_06',
#   'use_amt패스트푸드18_06',
#   'work_pop_cnt장기해외제주21_06'],
#  '조천읍7~12': ['em_g18_12',
#   'visit_pop_cnt단기해외18_12',
#   'work_pop_cnt장기해외제주20_12',
#   'resd_pop_cnt장기해외제주18_12',
#   'visit_pop_cnt내국인남성그외18_12'],
#  '중문동1~6': ['foreign_pop남성21_06',
#   'work_pop_cnt내국인남성제주20_06',
#   'work_pop_cnt내국인여성그외20_06',
#   'work_pop_cnt장기해외그외20_06'],
#  '중문동7~12': ['resd_pop_cnt내국인여성제주19_12',
#   'use_amt주점및주류판매20_12',
#   'visit_pop_cnt장기해외제주20_12',
#   'visit_pop_cnt장기해외그외19_12'],
#  '중앙동1~6': ['use_amt식품19_06',
#   'work_pop_cnt장기해외그외21_06',
#   'work_pop_cnt장기해외제주20_06',
#   'work_pop_cnt내국인여성제주21_06'],
#  '중앙동7~12': ['work_pop_cnt장기해외그외20_12',
#   'use_amt배달20_12',
#   'visit_pop_cnt장기해외그외20_12',
#   'visit_pop_cnt장기해외그외19_12'],
#  '천지동1~6': ['use_amt부페21_06',
#   'use_amt마트/슈퍼마켓21_06',
#   'visit_pop_cnt단기해외21_06',
#   'visit_pop_cnt장기해외제주20_06',
#   'use_amt패스트푸드18_06'],
#  '천지동7~12': ['use_amt한식18_12',
#   'foreign_pop여성18_12',
#   'work_pop_cnt장기해외제주20_12',
#   'visit_pop_cnt내국인여성제주19_12'],
#  '표선면1~6': ['resid_reg_pop남성19_06',
#   'resd_pop_cnt장기해외제주18_06',
#   'work_pop_cnt장기해외그외21_06',
#   'use_amt패스트푸드21_06'],
#  '표선면7~12': ['work_pop_cnt장기해외그외18_12'],
#  '한경면1~6': ['use_amt한식18_06',
#   'use_amt양식20_06',
#   'em_g19_06',
#   'em_g18_06',
#   'use_amt배달18_06',
#   'use_amt아시아음식18_06'],
#  '한경면7~12': ['use_amt부페20_12',
#   'em_g18_12',
#   'resd_pop_cnt장기해외제주19_12',
#   'use_amt부페18_12',
#   'use_amt아시아음식18_12',
#   'work_pop_cnt내국인여성제주18_12'],
#  '한림읍1~6': ['foreign_pop여성21_06',
#   'foreign_pop여성18_06',
#   'foreign_pop남성21_06',
#   'em_g19_06',
#   'foreign_pop남성20_06',
#   'em_g18_06',
#   'foreign_pop남성19_06',
#   'work_pop_cnt장기해외그외18_06',
#   'foreign_pop남성18_06',
#   'foreign_pop여성19_06',
#   'foreign_pop여성20_06',
#   'resid_reg_pop여성18_06',
#   'use_amt주점및주류판매19_06',
#   'use_amt마트/슈퍼마켓19_06',
#   'use_amt간식19_06'],
#  '한림읍7~12': ['em_g18_12',
#   'foreign_pop남성19_12',
#   'foreign_pop남성18_12',
#   'foreign_pop여성19_12',
#   'foreign_pop남성20_12',
#   'work_pop_cnt장기해외그외18_12',
#   'foreign_pop여성20_12',
#   'foreign_pop여성18_12'],
#  '화북동1~6': ['use_amt식품19_06', 'use_amt주점및주류판매21_06'],
#  '화북동7~12': ['work_pop_cnt내국인남성제주20_12',
#   'visit_pop_cnt내국인남성제주20_12',
#   'work_pop_cnt장기해외그외18_12',
#   'visit_pop_cnt내국인남성제주18_12'],
#  '효돈동1~6': ['visit_pop_cnt장기해외그외21_06',
#   'resd_pop_cnt내국인남성제주21_06',
#   'use_amt농축수산물21_06',
#   'use_amt양식19_06'],
#  '효돈동7~12': ['visit_pop_cnt장기해외그외19_12', 'use_amt부페20_12']}
