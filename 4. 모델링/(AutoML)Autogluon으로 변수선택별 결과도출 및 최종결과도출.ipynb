# %%
# !pip install autogluon

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import time
from sklearn.preprocessing import MinMaxScaler

from autogluon.tabular import TabularDataset
from autogluon.tabular import TabularPredictor as task

# %matplotlib inline

print("pandas version: ", pd.__version__)
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)

import warnings
warnings.filterwarnings(action='ignore')
# Out:
# pandas version:  1.1.5

# %% [markdown]
# # 여러 변수제거한 경우별로 성능평가

# %%
#### 2. 데이터 불러오기 ####
#  변수선택 111

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
#delete_list = delete_list + ['sexratio']

#인구수
delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
#delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습

# %%
#### 2. 데이터 불러오기 ####
#  변수선택 112

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
#delete_list = delete_list + ['sexratio']

#인구수
#delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_042407/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_042407/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 93
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12501.75 MB
# 	Train Data (Original)  Memory Usage: 1.17 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  변수선택 121

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
#delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
delete_list = delete_list + ['sexratio']

#인구수
delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
#delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_043026/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_043026/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 98
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12459.6 MB
# 	Train Data (Original)  Memory Usage: 1.23 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  변수선택 122

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
#delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
delete_list = delete_list + ['sexratio']

#인구수
#delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_043331/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_043331/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 97
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12439.14 MB
# 	Train Data (Original)  Memory Usage: 1.22 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  변수선택 211

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
#delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
#delete_list = delete_list + ['sexratio']

#인구수
delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
#delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_044326/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_044326/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 87
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12422.56 MB
# 	Train Data (Original)  Memory Usage: 1.1 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  변수선택 212

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
#delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
#delete_list = delete_list + ['sexratio']

#인구수
#delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_044655/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_044655/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 86
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12385.27 MB
# 	Train Data (Original)  Memory Usage: 1.09 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  변수선택 221

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
#delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
#delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
delete_list = delete_list + ['sexratio']

#인구수
delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
#delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_045001/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_045001/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 91
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12367.33 MB
# 	Train Data (Original)  Memory Usage: 1.15 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  변수선택 222

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
#delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
#delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
delete_list = delete_list + ['sexratio']

#인구수
#delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_045238/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_045238/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 90
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12352.17 MB
# 	Train Data (Original)  Memory Usage: 1.14 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  변수선택 311

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
#delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
#delete_list = delete_list + ['sexratio']

#인구수
delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
#delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_045816/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_045816/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 89
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12329.25 MB
# 	Train Data (Original)  Memory Usage: 1.13 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  변수선택 312

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
#delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
#delete_list = delete_list + ['sexratio']

#인구수
#delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_050049/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_050049/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 88
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12315.64 MB
# 	Train Data (Original)  Memory Usage: 1.11 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  변수선택 321

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
#delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
#delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
delete_list = delete_list + ['sexratio']

#인구수
delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
#delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_050447/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_050447/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 93
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12291.94 MB
# 	Train Data (Original)  Memory Usage: 1.17 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  변수선택 322

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
#delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
#delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
delete_list = delete_list + ['sexratio']

#인구수
#delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_050810/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_050810/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 92
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12271.38 MB
# 	Train Data (Original)  Memory Usage: 1.16 MB (0.0% of available memory)
# ...

# %% [markdown]
# # 여러 변수묶음중 한 묶음씩만 제거하고 성능평가

# %%
#### 2. 데이터 불러오기 ####
#  유동1

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')


delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
#delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
#delete_list = delete_list + ['sexratio']

#인구수
#delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
#delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_060053/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_060053/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 102
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12070.32 MB
# 	Train Data (Original)  Memory Usage: 1.28 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  유동2

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')


delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
#delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
#delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
#delete_list = delete_list + ['sexratio']

#인구수
#delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
#delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_060453/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_060453/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 95
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12058.37 MB
# 	Train Data (Original)  Memory Usage: 1.2 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  유동3

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
#delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
#delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
#delete_list = delete_list + ['sexratio']

#인구수
#delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
#delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_060900/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_060900/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 97
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12030.76 MB
# 	Train Data (Original)  Memory Usage: 1.22 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  성비1

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')


delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
#delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
#delete_list = delete_list + ['sexratio']

#인구수
#delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
#delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_061541/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_061541/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 111
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12005.08 MB
# 	Train Data (Original)  Memory Usage: 1.38 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  성비2

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')


delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
#delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
#delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
delete_list = delete_list + ['sexratio']

#인구수
#delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
#delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_062142/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_062142/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 115
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11969.56 MB
# 	Train Data (Original)  Memory Usage: 1.43 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  인구수1

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')


delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
#delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
#delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
#delete_list = delete_list + ['sexratio']

#인구수
delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
#delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_062550/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_062550/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 113
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11952.16 MB
# 	Train Data (Original)  Memory Usage: 1.41 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  인구수2

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')



delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
#delete_list = delete_list + ['resd_pop','visit_pop','work_pop','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']
#delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop','visit_pop','work_pop']

#성비
#delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']
#delete_list = delete_list + ['sexratio']

#인구수
#delete_list = delete_list + ['foreign_pop','resid_reg_pop','total_pop']
delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습#______________
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_063000/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_063000/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 112
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11938.92 MB
# 	Train Data (Original)  Memory Usage: 1.39 MB (0.0% of available memory)
# ...

# %% [markdown]
# # 클러스터별 유동인구2, 성비1, 인구2 택한것의 성능평가

# %%
#유동인구 2,성비1,인구2만 클러1
df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

clust = 1

df2_train = df2_train[df2_train['clustered']==clust]        


delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']

#성비
delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']

#인구수
delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습#______________
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_064840/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_064840/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    720
# Train Data Columns: 86
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (135774149.0, 3389450.0, 41486651.05724, 26963403.96569)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11907.52 MB
# 	Train Data (Original)  Memory Usage: 0.54 MB (0.0% of available memory)
# ...

# %%
#유동인구 2,성비1,인구2만 클러2
df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

clust = 2

df2_train = df2_train[df2_train['clustered']==clust]        


delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']

#성비
delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']

#인구수
delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습#______________
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_064933/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_064933/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    560
# Train Data Columns: 86
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 7451200.0, 106162666.2812, 75401561.32908)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11900.54 MB
# 	Train Data (Original)  Memory Usage: 0.42 MB (0.0% of available memory)
# ...

# %%
#유동인구 2,성비1,인구2만 클러3
df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

clust = 3

df2_train = df2_train[df2_train['clustered']==clust]        


delete_list = ['Unnamed: 0','emd_nm','clustered']
#유동인구
delete_list = delete_list + ['resd_pop_cnt내국인남성제주','resd_pop_cnt내국인여성제주','visit_pop_cnt내국인남성그외','visit_pop_cnt내국인남성제주','visit_pop_cnt내국인여성그외','visit_pop_cnt내국인여성제주','work_pop_cnt내국인남성그외','work_pop_cnt내국인남성제주','work_pop_cnt내국인여성그외','work_pop_cnt내국인여성제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외','resd_pop_cnt내국인제주','visit_pop_cnt내국인그외','visit_pop_cnt내국인제주','work_pop_cnt내국인그외','work_pop_cnt내국인제주','resd_pop_cnt장기해외제주','visit_pop_cnt장기해외그외','visit_pop_cnt장기해외제주','work_pop_cnt장기해외그외','work_pop_cnt장기해외제주','visit_pop_cnt단기해외']

#성비
delete_list = delete_list + ['foreign_pop_gender_ratio','total_pop_gender_ratio','resd_pop_cnt_gender_ratio','visit_pop_cnt_gender_ratio','work_pop_cnt_gender_ratio']

#인구수
delete_list = delete_list + ['foreign_pop남성','foreign_pop여성','resid_reg_pop남성','resid_reg_pop여성']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습#______________
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_065049/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_065049/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    179
# Train Data Columns: 86
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (113929800.0, 1910750.0, 47293833.0581, 29469735.52483)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11888.07 MB
# 	Train Data (Original)  Memory Usage: 0.13 MB (0.0% of available memory)
# ...

# %% [markdown]
# # 전체성능과 클러스터별 성능 평가

# %%
#### 2. 데이터 불러오기 ####
#  전체와 클러스터별 성능 비교

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')    


delete_list = ['Unnamed: 0','emd_nm','clustered']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_051138/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_051138/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 116
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12246.68 MB
# 	Train Data (Original)  Memory Usage: 1.44 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  전체와 클러스터별 성능 비교

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

clust = 1

df2_train = df2_train[df2_train['clustered']==clust]        


delete_list = ['Unnamed: 0','emd_nm','clustered']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_051559/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_051559/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    720
# Train Data Columns: 116
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (135774149.0, 3389450.0, 41486651.05724, 26963403.96569)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12244.9 MB
# 	Train Data (Original)  Memory Usage: 0.71 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  전체와 클러스터별 성능 비교

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

clust = 2

df2_train = df2_train[df2_train['clustered']==clust]        


delete_list = ['Unnamed: 0','emd_nm','clustered']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_051811/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_051811/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    560
# Train Data Columns: 116
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 7451200.0, 106162666.2812, 75401561.32908)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12228.88 MB
# 	Train Data (Original)  Memory Usage: 0.55 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  전체와 클러스터별 성능 비교

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

clust = 3

df2_train = df2_train[df2_train['clustered']==clust]        


delete_list = ['Unnamed: 0','emd_nm','clustered']

df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_052315/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_052315/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    179
# Train Data Columns: 116
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (113929800.0, 1910750.0, 47293833.0581, 29469735.52483)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12221.07 MB
# 	Train Data (Original)  Memory Usage: 0.18 MB (0.0% of available memory)
# ...

# %% [markdown]
# # OLS선택법 결과를 제거하고 전체 및 클러스터별 성능평가

# %%
#OLS 선택법 가장선택안된 8개

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')
      

delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외', 'visit_pop_cnt내국인그외', 'resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타']
#delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외','visit_pop_cnt내국인그외','resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타','corona_infec','vac_2nd','mon','total_pop남성','resd_per_visit','work_pop_cnt내국인제주','visit_pop_cnt_gender_ratio','visit_pop_cnt_장기_아시아','visit_pop_cnt_장기_아프리카','visit_pop_cnt_장기_오세아니아','work_pop_cnt_장기_아프리카']


df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_065111/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_065111/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 107
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11884.24 MB
# 	Train Data (Original)  Memory Usage: 1.34 MB (0.0% of available memory)
# ...

# %%
#OLS 선택법 가장선택안된 8개 클러1

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

clust = 1

df2_train = df2_train[df2_train['clustered']==clust]        

delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외', 'visit_pop_cnt내국인그외', 'resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타']
#delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외','visit_pop_cnt내국인그외','resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타','corona_infec','vac_2nd','mon','total_pop남성','resd_per_visit','work_pop_cnt내국인제주','visit_pop_cnt_gender_ratio','visit_pop_cnt_장기_아시아','visit_pop_cnt_장기_아프리카','visit_pop_cnt_장기_오세아니아','work_pop_cnt_장기_아프리카']


df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_065454/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_065454/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    720
# Train Data Columns: 107
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (135774149.0, 3389450.0, 41486651.05724, 26963403.96569)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11869.45 MB
# 	Train Data (Original)  Memory Usage: 0.66 MB (0.0% of available memory)
# ...

# %%
#OLS 선택법 가장선택안된 8개 클러2

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

clust = 2

df2_train = df2_train[df2_train['clustered']==clust]        

delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외', 'visit_pop_cnt내국인그외', 'resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타']
#delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외','visit_pop_cnt내국인그외','resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타','corona_infec','vac_2nd','mon','total_pop남성','resd_per_visit','work_pop_cnt내국인제주','visit_pop_cnt_gender_ratio','visit_pop_cnt_장기_아시아','visit_pop_cnt_장기_아프리카','visit_pop_cnt_장기_오세아니아','work_pop_cnt_장기_아프리카']


df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_065722/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_065722/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    560
# Train Data Columns: 107
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 7451200.0, 106162666.2812, 75401561.32908)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11853.37 MB
# 	Train Data (Original)  Memory Usage: 0.51 MB (0.0% of available memory)
# ...

# %%
#OLS 선택법 가장선택안된 8개 클러3

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

clust = 3

df2_train = df2_train[df2_train['clustered']==clust]        

delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외', 'visit_pop_cnt내국인그외', 'resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타']
#delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외','visit_pop_cnt내국인그외','resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타','corona_infec','vac_2nd','mon','total_pop남성','resd_per_visit','work_pop_cnt내국인제주','visit_pop_cnt_gender_ratio','visit_pop_cnt_장기_아시아','visit_pop_cnt_장기_아프리카','visit_pop_cnt_장기_오세아니아','work_pop_cnt_장기_아프리카']


df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_070030/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_070030/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    179
# Train Data Columns: 107
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (113929800.0, 1910750.0, 47293833.0581, 29469735.52483)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11831.78 MB
# 	Train Data (Original)  Memory Usage: 0.16 MB (0.0% of available memory)
# ...

# %%
#OLS 선택법 가장선택안된 8개와 거의안된 11개 전체

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')
      

#delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외', 'visit_pop_cnt내국인그외', 'resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타']
delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외','visit_pop_cnt내국인그외','resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타','corona_infec','vac_2nd','mon','total_pop남성','resd_per_visit','work_pop_cnt내국인제주','visit_pop_cnt_gender_ratio','visit_pop_cnt_장기_아시아','visit_pop_cnt_장기_아프리카','visit_pop_cnt_장기_오세아니아','work_pop_cnt_장기_아프리카']


df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_070054/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_070054/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1459
# Train Data Columns: 96
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 1910750.0, 67023357.09122, 60021230.60654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11831.88 MB
# 	Train Data (Original)  Memory Usage: 1.21 MB (0.0% of available memory)
# ...

# %%
#OLS 선택법 가장선택안된 8개와 거의안된 11개 클러1

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

clust = 1

df2_train = df2_train[df2_train['clustered']==clust]        

#delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외', 'visit_pop_cnt내국인그외', 'resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타']
delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외','visit_pop_cnt내국인그외','resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타','corona_infec','vac_2nd','mon','total_pop남성','resd_per_visit','work_pop_cnt내국인제주','visit_pop_cnt_gender_ratio','visit_pop_cnt_장기_아시아','visit_pop_cnt_장기_아프리카','visit_pop_cnt_장기_오세아니아','work_pop_cnt_장기_아프리카']


df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_070804/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_070804/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    720
# Train Data Columns: 96
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (135774149.0, 3389450.0, 41486651.05724, 26963403.96569)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11827.95 MB
# 	Train Data (Original)  Memory Usage: 0.6 MB (0.0% of available memory)
# ...

# %%
#OLS 선택법 가장선택안된 8개와 거의안된 11개 클러2

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

clust = 2

df2_train = df2_train[df2_train['clustered']==clust]        

#delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외', 'visit_pop_cnt내국인그외', 'resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타']
delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외','visit_pop_cnt내국인그외','resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타','corona_infec','vac_2nd','mon','total_pop남성','resd_per_visit','work_pop_cnt내국인제주','visit_pop_cnt_gender_ratio','visit_pop_cnt_장기_아시아','visit_pop_cnt_장기_아프리카','visit_pop_cnt_장기_오세아니아','work_pop_cnt_장기_아프리카']


df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_072236/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_072236/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    560
# Train Data Columns: 96
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 7451200.0, 106162666.2812, 75401561.32908)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11806.11 MB
# 	Train Data (Original)  Memory Usage: 0.46 MB (0.0% of available memory)
# ...

# %%
#OLS 선택법 가장선택안된 8개와 거의안된 11개 클러3

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

clust = 3

df2_train = df2_train[df2_train['clustered']==clust]        

#delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외', 'visit_pop_cnt내국인그외', 'resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타']
delete_list = ['Unnamed: 0','emd_nm','clustered','visit_pop_cnt장기해외그외','visit_pop_cnt내국인그외','resd_pop_cnt_gender_ratio','resd_pop_cnt장기_아프리카','visit_pop_cnt_장기_기타','work_pop_cnt_장기_기타','work_pop_cnt_장기_오세아니아','work_pop_cnt_장기_유럽','visit_pop_cnt_단기_기타','corona_infec','vac_2nd','mon','total_pop남성','resd_per_visit','work_pop_cnt내국인제주','visit_pop_cnt_gender_ratio','visit_pop_cnt_장기_아시아','visit_pop_cnt_장기_아프리카','visit_pop_cnt_장기_오세아니아','work_pop_cnt_장기_아프리카']


df2_train = df2_train.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_071130/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_071130/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    179
# Train Data Columns: 96
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (113929800.0, 1910750.0, 47293833.0581, 29469735.52483)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11804.55 MB
# 	Train Data (Original)  Memory Usage: 0.15 MB (0.0% of available memory)
# ...

# %% [markdown]
# # 클러스터링별 예측

# %%
#### 2. 데이터 불러오기 ####
#  트레인 테스트 진짜로 하는거

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')
df2_test = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_test_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

clust = 1

df2_train = df2_train[df2_train['clustered']==clust]        
df2_test = df2_test[df2_test['clustered']==clust]        

delete_list = ['Unnamed: 0','emd_nm','clustered']

df2_train = df2_train.drop(delete_list, axis=1)
df2_test = df2_test.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
results = predictor.fit_summary()
perf = predictor.evaluate(df2_test)
results
perf
predictions = predictor.predict(df2_test) #테스트 데이터에 대한 예측
predictions
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210915_003526/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210915_003526/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    720
# Train Data Columns: 116
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (135774149.0, 3389450.0, 41486651.05724, 26963403.96569)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12657.01 MB
# 	Train Data (Original)  Memory Usage: 0.71 MB (0.0% of available memory)
# ...

# %%
predictor.evaluate(df2_test)
# Out:
# Evaluation: root_mean_squared_error on test data: -52784228.621263154
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -52784228.621263154,
#     "mean_squared_error": -2786174791141776.5,
#     "mean_absolute_error": -46737028.55555555,
#     "r2": 0.0,
#     "pearsonr": NaN,
#     "median_absolute_error": -40020990.0
# }
# {'mean_absolute_error': -46737028.55555555,
#  'mean_squared_error': -2786174791141776.5,
#  'median_absolute_error': -40020990.0,
#  'pearsonr': nan,
#  'r2': 0.0,
#  'root_mean_squared_error': -52784228.621263154}

# %%
#### 2. 데이터 불러오기 ####
#  A-2월로 A월 예측

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')
df2_test = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_test_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

clust = 2

df2_train = df2_train[df2_train['clustered']==clust]        
df2_test = df2_test[df2_test['clustered']==clust]        


delete_list = ['Unnamed: 0','emd_nm','clustered']

df2_train = df2_train.drop(delete_list, axis=1)
df2_test = df2_test.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
results = predictor.fit_summary()
perf = predictor.evaluate(df2_test)
results
perf
predictions = predictor.predict(df2_test) #테스트 데이터에 대한 예측
predictions
predictor.feature_importance(df2_train, model='WeightedEnsemble_L2', feature_stage = 'transformed_model')
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210914_205342/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210914_205342/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    560
# Train Data Columns: 116
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (327483750.0, 7451200.0, 106162666.2812, 75401561.32908)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12563.17 MB
# 	Train Data (Original)  Memory Usage: 0.55 MB (0.0% of available memory)
# ...

# %%
#### 2. 데이터 불러오기 ####
#  A-2월로 A월 예측

df2_train = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_train_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')
df2_test = pd.read_csv('/content/drive/Shareddrives/알빠진 포도/데이터 모음집/df2_test_최종_13일클러변경.csv', encoding='cp949', index_col='emd_nm_2term')

clust = 3

df2_train = df2_train[df2_train['clustered']==clust]        
df2_test = df2_test[df2_test['clustered']==clust]        


delete_list = ['Unnamed: 0','emd_nm','clustered']

df2_train = df2_train.drop(delete_list, axis=1)
df2_test = df2_test.drop(delete_list, axis=1)

predictor = task(label='em_g_interpolated').fit(train_data = df2_train ) #학습
results = predictor.fit_summary()
perf = predictor.evaluate(df2_test)
results
perf
predictions = predictor.predict(df2_test) #테스트 데이터에 대한 예측
predictions
predictor.feature_importance(df2_train, model='WeightedEnsemble_L2', feature_stage = 'transformed_model')
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20210915_024101/"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20210915_024101/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    179
# Train Data Columns: 116
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (113929800.0, 1910750.0, 47293833.0581, 29469735.52483)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12656.08 MB
# 	Train Data (Original)  Memory Usage: 0.18 MB (0.0% of available memory)
# ...

# %%
#변수중요도
predictor.feature_importance(df2_train, model='WeightedEnsemble_L2', feature_stage = 'transformed_model')  #어떤 모델이 많이 앙상블되었는지 보기
task.feature_importance(predictor, model='WeightedEnsemble_L2', features=df2_train.columns.tolist()[1:], feature_stage = 'transformed')  #어떤 변수가 많이 쓰였는지 보기
# Out:
# ...
#           importance  stddev  p_score   n  p99_high  p99_low
# CatBoost    0.894118     NaN      NaN NaN       NaN      NaN
# XGBoost     0.105882     NaN      NaN NaN       NaN      NaN
